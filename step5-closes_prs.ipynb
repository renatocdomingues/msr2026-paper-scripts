# %%
import pandas as pd
import requests
import time
from tqdm import tqdm
from collections import Counter

# %%
GITHUB_TOKEN = "INSERT_TOKEN"
headers = {
    "Authorization": f"token {GITHUB_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

# %%
path_to_file = r'output_files\prs_reviews.csv'
closed_prs = pd.read_csv(path_to_file)

# %%
has_reviews = closed_prs[closed_prs['reviews_data'].str.len() > 2]
has_reviews
# Out:
#               id  number                       user    user_id  agent  \
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 1     2265431531   83085                ArthurKnaus    7033940  Human
# 2     2622011651   94465                     bukzor     640328  Human
# 3     2565399631   92785                     dashed     139499  Human
# 4     2374801945   86438             brendanhsentry  171613822  Human
# ...          ...     ...                        ...        ...    ...
# 9037  3152227876    2121  devin-ai-integration[bot]  158243242  Devin
# 9042  2876371914   54663  devin-ai-integration[bot]  158243242  Devin
# 9045  3275451449    2766  devin-ai-integration[bot]  158243242  Devin
# 9046  3260325787    1541  devin-ai-integration[bot]  158243242  Devin
# 9047  3260452571    1542  devin-ai-integration[bot]  158243242  Devin
#
#                                                repo_url  \
# 0         https://api.github.com/repos/getsentry/sentry
# 1         https://api.github.com/repos/getsentry/sentry
# 2         https://api.github.com/repos/getsentry/sentry
# 3         https://api.github.com/repos/getsentry/sentry
# 4         https://api.github.com/repos/getsentry/sentry
# ...                                                 ...
# 9037  https://api.github.com/repos/assistant-ui/assi...
# 9042     https://api.github.com/repos/airbytehq/airbyte
# 9045          https://api.github.com/repos/liam-hq/liam
# 9046  https://api.github.com/repos/reflex-dev/reflex...
# 9047  https://api.github.com/repos/reflex-dev/reflex...
#
#                                                html_url  \
# 0        https://github.com/getsentry/sentry/pull/88748
# 1        https://github.com/getsentry/sentry/pull/83085
# 2        https://github.com/getsentry/sentry/pull/94465
# 3        https://github.com/getsentry/sentry/pull/92785
# 4        https://github.com/getsentry/sentry/pull/86438
# ...                                                 ...
# 9037  https://github.com/assistant-ui/assistant-ui/p...
# 9042    https://github.com/airbytehq/airbyte/pull/54663
# 9045          https://github.com/liam-hq/liam/pull/2766
# 9046  https://github.com/reflex-dev/reflex-web/pull/...
# 9047  https://github.com/reflex-dev/reflex-web/pull/...
#
#                                             reviews_url  \
# 0     https://api.github.com/repos/getsentry/sentry/...
# 1     https://api.github.com/repos/getsentry/sentry/...
# 2     https://api.github.com/repos/getsentry/sentry/...
# 3     https://api.github.com/repos/getsentry/sentry/...
# 4     https://api.github.com/repos/getsentry/sentry/...
# ...                                                 ...
# 9037  https://api.github.com/repos/assistant-ui/assi...
# 9042  https://api.github.com/repos/airbytehq/airbyte...
# 9045  https://api.github.com/repos/liam-hq/liam/pull...
# 9046  https://api.github.com/repos/reflex-dev/reflex...
# 9047  https://api.github.com/repos/reflex-dev/reflex...
#
#                                            reviews_data  \
# 0     [{'user': 'GabeVillalobos', 'state': 'COMMENTE...
# 1     [{'user': 'obostjancic', 'state': 'APPROVED', ...
# 2     [{'user': 'joshuarli', 'state': 'APPROVED', 'b...
# 3     [{'user': 'isabellaenriquez', 'state': 'APPROV...
# 4     [{'user': 'isabellaenriquez', 'state': 'APPROV...
# ...                                                 ...
# 9037  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 9042  [{'user': 'pnilan', 'state': 'APPROVED', 'body...
# 9045  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 9046  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 9047  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                                       review_counts_map
# 0                                 {'GabeVillalobos': 2}
# 1                                    {'obostjancic': 1}
# 2                                      {'joshuarli': 1}
# 3                               {'isabellaenriquez': 1}
# 4                  {'isabellaenriquez': 1, 'dashed': 1}
# ...                                                 ...
# 9037                          {'greptile-apps[bot]': 1}
# 9042                                      {'pnilan': 1}
# 9045  {'MH4GF': 3, 'copilot-pull-request-reviewer[bo...
# 9046           {'greptile-apps[bot]': 1, 'Lendemor': 1}
# 9047           {'greptile-apps[bot]': 1, 'Lendemor': 1}
#
# [3323 rows x 10 columns]

# %%
# --- 1. Preparação das colunas ---
# Garantir que as colunas existam para não dar erro de atribuição depois
if 'closed_by_user' not in has_reviews.columns:
    has_reviews['closed_by_user'] = None
if 'closing_method' not in has_reviews.columns:
    has_reviews['closing_method'] = None

# Filtra apenas quem ainda não tem a informação (para economizar API se rodar de novo)
prs_para_processar = has_reviews[has_reviews['closed_by_user'].isna()].copy()

print(f"Processando {len(prs_para_processar)} PRs...")
# Out:
# Processando 3323 PRs...
# C:\Users\Renato\AppData\Local\Temp\ipykernel_10880\1612956348.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_reviews['closed_by_user'] = None
# C:\Users\Renato\AppData\Local\Temp\ipykernel_10880\1612956348.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_reviews['closing_method'] = None

# %%
# --- FUNÇÃO INTELIGENTE COM AUTO-SLEEP ---
def get_pr_closure_info(row):
    url_pr = f"{row['repo_url']}/pulls/{row['number']}"
    
    try:
        # TENTATIVA 1: Endpoint da PR
        response = requests.get(url_pr, headers=headers, timeout=10)
        
        # Se der Rate Limit (403), dorme e tenta de novo
        if response.status_code == 403 and 'X-RateLimit-Reset' in response.headers:
            reset_time = int(response.headers['X-RateLimit-Reset'])
            sleep_time = reset_time - time.time() + 10 # +10s de segurança
            if sleep_time > 0:
                print(f"\n⛔ Rate Limit atingido! Dormindo {sleep_time/60:.1f} min...")
                time.sleep(sleep_time)
                return get_pr_closure_info(row) # Tenta de novo (recursão)

        if response.status_code == 200:
            data = response.json()
            if data.get('merged_by'):
                return data['merged_by']['login'], 'Merged'
            if data.get('state') == 'closed' and data.get('closed_by'):
                if data.get('merged_at'): 
                    return data['closed_by']['login'], 'Merged'
                return data['closed_by']['login'], 'Closed'

        # TENTATIVA 2: Fallback para Timeline
        url_events = f"{row['repo_url']}/issues/{row['number']}/events"
        resp_events = requests.get(url_events, headers=headers, timeout=10)
        
        # Rate Limit na Timeline
        if resp_events.status_code == 403 and 'X-RateLimit-Reset' in resp_events.headers:
            reset_time = int(resp_events.headers['X-RateLimit-Reset'])
            sleep_time = reset_time - time.time() + 10
            if sleep_time > 0:
                print(f"\n⛔ Rate Limit (Timeline)! Dormindo {sleep_time/60:.1f} min...")
                time.sleep(sleep_time)
                return get_pr_closure_info(row)
        
        if resp_events.status_code == 200:
            events = resp_events.json()
            # Procura Merge
            for event in events:
                if event['event'] == 'merged':
                    actor = event.get('actor')
                    return (actor.get('login') if actor else 'Ghost/Deleted'), 'Merged'
            # Procura Closed
            for event in events:
                if event['event'] == 'closed':
                    actor = event.get('actor')
                    return (actor.get('login') if actor else 'Ghost/Deleted'), 'Closed'

    except Exception as e:
        print(f"\nErro na PR {row.get('number')}: {e}")
        
    return None, None

# --- EXECUÇÃO DO LOOP ---
print("Iniciando processamento com Auto-Sleep ativado...")

# Filtra apenas o que falta processar
prs_para_processar = has_reviews[has_reviews['closed_by_user'].isna()]

for idx, row in tqdm(prs_para_processar.iterrows(), total=len(prs_para_processar)):
    user, method = get_pr_closure_info(row)
    
    if user:
        # Usa .loc para evitar o erro "must be a scalar"
        has_reviews.loc[idx, 'closed_by_user'] = user
        has_reviews.loc[idx, 'closing_method'] = method

print("\nFinalizado!")
has_reviews.head()
# Out:
# Iniciando processamento com Auto-Sleep ativado...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3323/3323 [1:00:42<00:00,  1.10s/it]
# Finalizado!
#            id  number            user    user_id  agent  \
# 0  2438086945   88748     iamrajjoshi   33237075  Human
# 1  2265431531   83085     ArthurKnaus    7033940  Human
# 2  2622011651   94465          bukzor     640328  Human
# 3  2565399631   92785          dashed     139499  Human
# 4  2374801945   86438  brendanhsentry  171613822  Human
#
#                                         repo_url  \
# 0  https://api.github.com/repos/getsentry/sentry
# 1  https://api.github.com/repos/getsentry/sentry
# 2  https://api.github.com/repos/getsentry/sentry
# 3  https://api.github.com/repos/getsentry/sentry
# 4  https://api.github.com/repos/getsentry/sentry
#
#                                          html_url  \
# 0  https://github.com/getsentry/sentry/pull/88748
# 1  https://github.com/getsentry/sentry/pull/83085
# 2  https://github.com/getsentry/sentry/pull/94465
# 3  https://github.com/getsentry/sentry/pull/92785
# 4  https://github.com/getsentry/sentry/pull/86438
#
#                                          reviews_url  \
# 0  https://api.github.com/repos/getsentry/sentry/...
# 1  https://api.github.com/repos/getsentry/sentry/...
# 2  https://api.github.com/repos/getsentry/sentry/...
# 3  https://api.github.com/repos/getsentry/sentry/...
# 4  https://api.github.com/repos/getsentry/sentry/...
#
#                                         reviews_data  \
# 0  [{'user': 'GabeVillalobos', 'state': 'COMMENTE...
# 1  [{'user': 'obostjancic', 'state': 'APPROVED', ...
# 2  [{'user': 'joshuarli', 'state': 'APPROVED', 'b...
# 3  [{'user': 'isabellaenriquez', 'state': 'APPROV...
# 4  [{'user': 'isabellaenriquez', 'state': 'APPROV...
#
#                       review_counts_map  closed_by_user closing_method
# 0                 {'GabeVillalobos': 2}     iamrajjoshi         Merged
# 1                    {'obostjancic': 1}     ArthurKnaus         Merged
# 2                      {'joshuarli': 1}          bukzor         Merged
# 3               {'isabellaenriquez': 1}          dashed         Merged
# 4  {'isabellaenriquez': 1, 'dashed': 1}  brendanhsentry         Merged

# %%
has_reviews[has_reviews['closing_method'].isna()]
# Out:
#               id  number                       user    user_id    agent  \
# 1845  3179981594    4265                    Copilot  198982749  Copilot
# 1859  3078439427   62036                    Copilot  198982749  Copilot
# 1912  3074609325  115732                    Copilot  198982749  Copilot
# 1913  3074618957  115733                    Copilot  198982749  Copilot
# 1930  3184463362   30291                    Copilot  198982749  Copilot
# 2042  3169212086    1704                    Copilot  198982749  Copilot
# 2069  3146392650   35272                    Copilot  198982749  Copilot
# 2165  3199881418   47088                    Copilot  198982749  Copilot
# 2248  3172846336    7729                    Copilot  198982749  Copilot
# 2258  3075857183  115762                    Copilot  198982749  Copilot
# 2298  3148248930   23052                    Copilot  198982749  Copilot
# 2357  3095028076    3688                    Copilot  198982749  Copilot
# 2473  3104375121   50357                    Copilot  198982749  Copilot
# 2502  3197983076    4260                    Copilot  198982749  Copilot
# 2555  3125459043  250880                    Copilot  198982749  Copilot
# 2563  3195365909   62539                    Copilot  198982749  Copilot
# 2573  3209908129    1657                    Copilot  198982749  Copilot
# 2630  3083905069   36050                    Copilot  198982749  Copilot
# 2656  3113703056  116256                    Copilot  198982749  Copilot
# 2902  3082188471    1623                    Copilot  198982749  Copilot
# 2972  3176732963   30218                    Copilot  198982749  Copilot
# 3013  3074847883    7397                    Copilot  198982749  Copilot
# 3091  3119354820   45590                    Copilot  198982749  Copilot
# 3105  3155815373     641                    Copilot  198982749  Copilot
# 3161  3223063338    1262                    Copilot  198982749  Copilot
# 3293  3231948361    4390                    Copilot  198982749  Copilot
# 7980  3222405821    2525  devin-ai-integration[bot]  158243242    Devin
# 8786  3015942635    1471  devin-ai-integration[bot]  158243242    Devin
#
#                                                repo_url  \
# 1845  https://api.github.com/repos/valkey-io/valkey-...
# 1859     https://api.github.com/repos/dotnet/aspnetcore
# 1912        https://api.github.com/repos/dotnet/runtime
# 1913        https://api.github.com/repos/dotnet/runtime
# 1930           https://api.github.com/repos/dotnet/maui
# 2042      https://api.github.com/repos/microsoft/retina
# 2069  https://api.github.com/repos/Azure/azure-rest-...
# 2165           https://api.github.com/repos/dotnet/docs
# 2248    https://api.github.com/repos/microsoft/typespec
# 2258        https://api.github.com/repos/dotnet/runtime
# 2298         https://api.github.com/repos/dotnet/macios
# 2357  https://api.github.com/repos/Azure/azure-conta...
# 2473  https://api.github.com/repos/Azure/azure-sdk-f...
# 2502  https://api.github.com/repos/microsoft/Applica...
# 2555      https://api.github.com/repos/microsoft/vscode
# 2563     https://api.github.com/repos/dotnet/aspnetcore
# 2573     https://api.github.com/repos/microsoft/openvmm
# 2630  https://api.github.com/repos/microsoft/playwright
# 2656        https://api.github.com/repos/dotnet/runtime
# 2902  https://api.github.com/repos/microsoft/finops-...
# 2972           https://api.github.com/repos/dotnet/maui
# 3013    https://api.github.com/repos/microsoft/typespec
# 3091  https://api.github.com/repos/Azure/azure-sdk-f...
# 3105  https://api.github.com/repos/hyperlight-dev/hy...
# 3161  https://api.github.com/repos/justtrackio/gosoline
# 3293  https://api.github.com/repos/valkey-io/valkey-...
# 7980          https://api.github.com/repos/liam-hq/liam
# 8786          https://api.github.com/repos/liam-hq/liam
#
#                                                html_url  \
# 1845  https://github.com/valkey-io/valkey-glide/pull...
# 1859    https://github.com/dotnet/aspnetcore/pull/62036
# 1912      https://github.com/dotnet/runtime/pull/115732
# 1913      https://github.com/dotnet/runtime/pull/115733
# 1930          https://github.com/dotnet/maui/pull/30291
# 2042      https://github.com/microsoft/retina/pull/1704
# 2069  https://github.com/Azure/azure-rest-api-specs/...
# 2165          https://github.com/dotnet/docs/pull/47088
# 2248    https://github.com/microsoft/typespec/pull/7729
# 2258      https://github.com/dotnet/runtime/pull/115762
# 2298        https://github.com/dotnet/macios/pull/23052
# 2357  https://github.com/Azure/azure-container-netwo...
# 2473  https://github.com/Azure/azure-sdk-for-net/pul...
# 2502  https://github.com/microsoft/ApplicationInsigh...
# 2555    https://github.com/microsoft/vscode/pull/250880
# 2563    https://github.com/dotnet/aspnetcore/pull/62539
# 2573     https://github.com/microsoft/openvmm/pull/1657
# 2630  https://github.com/microsoft/playwright/pull/3...
# 2656      https://github.com/dotnet/runtime/pull/116256
# 2902  https://github.com/microsoft/finops-toolkit/pu...
# 2972          https://github.com/dotnet/maui/pull/30218
# 3013    https://github.com/microsoft/typespec/pull/7397
# 3091  https://github.com/Azure/azure-sdk-for-java/pu...
# 3105  https://github.com/hyperlight-dev/hyperlight/p...
# 3161  https://github.com/justtrackio/gosoline/pull/1262
# 3293  https://github.com/valkey-io/valkey-glide/pull...
# 7980          https://github.com/liam-hq/liam/pull/2525
# 8786          https://github.com/liam-hq/liam/pull/1471
#
#                                             reviews_url  \
# 1845  https://api.github.com/repos/valkey-io/valkey-...
# 1859  https://api.github.com/repos/dotnet/aspnetcore...
# 1912  https://api.github.com/repos/dotnet/runtime/pu...
# 1913  https://api.github.com/repos/dotnet/runtime/pu...
# 1930  https://api.github.com/repos/dotnet/maui/pulls...
# 2042  https://api.github.com/repos/microsoft/retina/...
# 2069  https://api.github.com/repos/Azure/azure-rest-...
# 2165  https://api.github.com/repos/dotnet/docs/pulls...
# 2248  https://api.github.com/repos/microsoft/typespe...
# 2258  https://api.github.com/repos/dotnet/runtime/pu...
# 2298  https://api.github.com/repos/dotnet/macios/pul...
# 2357  https://api.github.com/repos/Azure/azure-conta...
# 2473  https://api.github.com/repos/Azure/azure-sdk-f...
# 2502  https://api.github.com/repos/microsoft/Applica...
# 2555  https://api.github.com/repos/microsoft/vscode/...
# 2563  https://api.github.com/repos/dotnet/aspnetcore...
# 2573  https://api.github.com/repos/microsoft/openvmm...
# 2630  https://api.github.com/repos/microsoft/playwri...
# 2656  https://api.github.com/repos/dotnet/runtime/pu...
# 2902  https://api.github.com/repos/microsoft/finops-...
# 2972  https://api.github.com/repos/dotnet/maui/pulls...
# 3013  https://api.github.com/repos/microsoft/typespe...
# 3091  https://api.github.com/repos/Azure/azure-sdk-f...
# 3105  https://api.github.com/repos/hyperlight-dev/hy...
# 3161  https://api.github.com/repos/justtrackio/gosol...
# 3293  https://api.github.com/repos/valkey-io/valkey-...
# 7980  https://api.github.com/repos/liam-hq/liam/pull...
# 8786  https://api.github.com/repos/liam-hq/liam/pull...
#
#                                            reviews_data  \
# 1845  [{'user': 'avifenesh', 'state': 'COMMENTED', '...
# 1859  [{'user': 'captainsafia', 'state': 'COMMENTED'...
# 1912  [{'user': 'danmoseley', 'state': 'COMMENTED', ...
# 1913  [{'user': 'segadora', 'state': 'COMMENTED', 'b...
# 1930  [{'user': 'PureWeen', 'state': 'CHANGES_REQUES...
# 2042  [{'user': 'agrawaliti', 'state': 'DISMISSED', ...
# 2069  [{'user': 'mikeharder', 'state': 'COMMENTED', ...
# 2165  [{'user': 'jkotas', 'state': 'COMMENTED', 'bod...
# 2248  [{'user': 'JoshLove-msft', 'state': 'COMMENTED...
# 2258  [{'user': 'tarekgh', 'state': 'COMMENTED', 'bo...
# 2298  [{'user': 'mandel-macaque', 'state': 'CHANGES_...
# 2357  [{'user': 'timraymond', 'state': 'CHANGES_REQU...
# 2473  [{'user': 'jsquire', 'state': 'COMMENTED', 'bo...
# 2502  [{'user': 'trask', 'state': 'COMMENTED', 'body...
# 2555  [{'user': 'meganrogge', 'state': 'COMMENTED', ...
# 2563  [{'user': 'ilonatommy', 'state': 'COMMENTED', ...
# 2573  [{'user': 'smmalis37', 'state': 'COMMENTED', '...
# 2630  [{'user': 'yury-s', 'state': 'COMMENTED', 'bod...
# 2656  [{'user': 'stephentoub', 'state': 'COMMENTED',...
# 2902  [{'user': 'RolandKrummenacher', 'state': 'COMM...
# 2972  [{'user': 'PureWeen', 'state': 'CHANGES_REQUES...
# 3013  [{'user': 'timotheeguerin', 'state': 'COMMENTE...
# 3091  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 3105  [{'user': 'ludfjig', 'state': 'COMMENTED', 'bo...
# 3161  [{'user': 'j4k4', 'state': 'CHANGES_REQUESTED'...
# 3293  [{'user': 'avifenesh', 'state': 'COMMENTED', '...
# 7980  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 8786  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
#
#                                       review_counts_map closed_by_user  \
# 1845                                   {'avifenesh': 3}           None
# 1859  {'captainsafia': 8, 'copilot-swe-agent[bot]': ...           None
# 1912     {'danmoseley': 1, 'copilot-swe-agent[bot]': 1}           None
# 1913                                    {'segadora': 1}           None
# 1930       {'PureWeen': 5, 'copilot-swe-agent[bot]': 5}           None
# 2042  {'agrawaliti': 2, 'SRodi': 3, 'copilot-swe-age...           None
# 2069     {'mikeharder': 1, 'copilot-swe-agent[bot]': 1}           None
# 2165  {'jkotas': 10, 'copilot-swe-agent[bot]': 10, '...           None
# 2248  {'JoshLove-msft': 7, 'copilot-swe-agent[bot]': 6}           None
# 2258  {'tarekgh': 4, 'copilot-swe-agent[bot]': 8, 'j...           None
# 2298  {'mandel-macaque': 4, 'copilot-swe-agent[bot]'...           None
# 2357    {'timraymond': 7, 'copilot-swe-agent[bot]': 13}           None
# 2473  {'jsquire': 12, 'copilot-swe-agent[bot]': 15, ...           None
# 2502          {'trask': 7, 'copilot-swe-agent[bot]': 5}           None
# 2555     {'meganrogge': 2, 'copilot-swe-agent[bot]': 2}           None
# 2563  {'ilonatommy': 3, 'copilot-swe-agent[bot]': 2,...           None
# 2573  {'smmalis37': 1, 'benhillis': 3, 'copilot-swe-...           None
# 2630        {'yury-s': 11, 'copilot-swe-agent[bot]': 6}           None
# 2656  {'stephentoub': 3, 'copilot-swe-agent[bot]': 3...           None
# 2902  {'RolandKrummenacher': 1, 'copilot-swe-agent[b...           None
# 2972       {'PureWeen': 2, 'copilot-swe-agent[bot]': 4}           None
# 3013  {'timotheeguerin': 1, 'copilot-swe-agent[bot]'...           None
# 3091  {'copilot-pull-request-reviewer[bot]': 1, 'srn...           None
# 3105  {'ludfjig': 2, 'simongdavies': 2, 'copilot-swe...           None
# 3161           {'j4k4': 1, 'copilot-swe-agent[bot]': 3}           None
# 3293      {'avifenesh': 4, 'copilot-swe-agent[bot]': 4}           None
# 7980          {'copilot-pull-request-reviewer[bot]': 1}           None
# 8786                                       {'MH4GF': 1}           None
#
#      closing_method
# 1845           None
# 1859           None
# 1912           None
# 1913           None
# 1930           None
# 2042           None
# 2069           None
# 2165           None
# 2248           None
# 2258           None
# 2298           None
# 2357           None
# 2473           None
# 2502           None
# 2555           None
# 2563           None
# 2573           None
# 2630           None
# 2656           None
# 2902           None
# 2972           None
# 3013           None
# 3091           None
# 3105           None
# 3161           None
# 3293           None
# 7980           None
# 8786           None

# %%
# Verifica se o valor é uma string E se não contém '[bot]'
has_reviews['has_human_closing_user'] = has_reviews['closed_by_user'].apply(
    lambda x: isinstance(x, str) and '[bot]' not in x
)

# Exibir o resultado
has_reviews
# Out:
# C:\Users\Renato\AppData\Local\Temp\ipykernel_10880\3156863303.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_reviews['has_human_closing_user'] = has_reviews['closed_by_user'].apply(
#               id  number                       user    user_id  agent  \
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 1     2265431531   83085                ArthurKnaus    7033940  Human
# 2     2622011651   94465                     bukzor     640328  Human
# 3     2565399631   92785                     dashed     139499  Human
# 4     2374801945   86438             brendanhsentry  171613822  Human
# ...          ...     ...                        ...        ...    ...
# 9037  3152227876    2121  devin-ai-integration[bot]  158243242  Devin
# 9042  2876371914   54663  devin-ai-integration[bot]  158243242  Devin
# 9045  3275451449    2766  devin-ai-integration[bot]  158243242  Devin
# 9046  3260325787    1541  devin-ai-integration[bot]  158243242  Devin
# 9047  3260452571    1542  devin-ai-integration[bot]  158243242  Devin
#
#                                                repo_url  \
# 0         https://api.github.com/repos/getsentry/sentry
# 1         https://api.github.com/repos/getsentry/sentry
# 2         https://api.github.com/repos/getsentry/sentry
# 3         https://api.github.com/repos/getsentry/sentry
# 4         https://api.github.com/repos/getsentry/sentry
# ...                                                 ...
# 9037  https://api.github.com/repos/assistant-ui/assi...
# 9042     https://api.github.com/repos/airbytehq/airbyte
# 9045          https://api.github.com/repos/liam-hq/liam
# 9046  https://api.github.com/repos/reflex-dev/reflex...
# 9047  https://api.github.com/repos/reflex-dev/reflex...
#
#                                                html_url  \
# 0        https://github.com/getsentry/sentry/pull/88748
# 1        https://github.com/getsentry/sentry/pull/83085
# 2        https://github.com/getsentry/sentry/pull/94465
# 3        https://github.com/getsentry/sentry/pull/92785
# 4        https://github.com/getsentry/sentry/pull/86438
# ...                                                 ...
# 9037  https://github.com/assistant-ui/assistant-ui/p...
# 9042    https://github.com/airbytehq/airbyte/pull/54663
# 9045          https://github.com/liam-hq/liam/pull/2766
# 9046  https://github.com/reflex-dev/reflex-web/pull/...
# 9047  https://github.com/reflex-dev/reflex-web/pull/...
#
#                                             reviews_url  \
# 0     https://api.github.com/repos/getsentry/sentry/...
# 1     https://api.github.com/repos/getsentry/sentry/...
# 2     https://api.github.com/repos/getsentry/sentry/...
# 3     https://api.github.com/repos/getsentry/sentry/...
# 4     https://api.github.com/repos/getsentry/sentry/...
# ...                                                 ...
# 9037  https://api.github.com/repos/assistant-ui/assi...
# 9042  https://api.github.com/repos/airbytehq/airbyte...
# 9045  https://api.github.com/repos/liam-hq/liam/pull...
# 9046  https://api.github.com/repos/reflex-dev/reflex...
# 9047  https://api.github.com/repos/reflex-dev/reflex...
#
#                                            reviews_data  \
# 0     [{'user': 'GabeVillalobos', 'state': 'COMMENTE...
# 1     [{'user': 'obostjancic', 'state': 'APPROVED', ...
# 2     [{'user': 'joshuarli', 'state': 'APPROVED', 'b...
# 3     [{'user': 'isabellaenriquez', 'state': 'APPROV...
# 4     [{'user': 'isabellaenriquez', 'state': 'APPROV...
# ...                                                 ...
# 9037  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 9042  [{'user': 'pnilan', 'state': 'APPROVED', 'body...
# 9045  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 9046  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 9047  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                                       review_counts_map  closed_by_user  \
# 0                                 {'GabeVillalobos': 2}     iamrajjoshi
# 1                                    {'obostjancic': 1}     ArthurKnaus
# 2                                      {'joshuarli': 1}          bukzor
# 3                               {'isabellaenriquez': 1}          dashed
# 4                  {'isabellaenriquez': 1, 'dashed': 1}  brendanhsentry
# ...                                                 ...             ...
# 9037                          {'greptile-apps[bot]': 1}           Yonom
# 9042                                      {'pnilan': 1}          pnilan
# 9045  {'MH4GF': 3, 'copilot-pull-request-reviewer[bo...   NoritakaIkeda
# 9046           {'greptile-apps[bot]': 1, 'Lendemor': 1}      adhami3310
# 9047           {'greptile-apps[bot]': 1, 'Lendemor': 1}    carlosabadia
#
#      closing_method  has_human_closing_user
# 0            Merged                    True
# 1            Merged                    True
# 2            Merged                    True
# 3            Merged                    True
# 4            Merged                    True
# ...             ...                     ...
# 9037         Closed                    True
# 9042         Merged                    True
# 9045         Merged                    True
# 9046         Merged                    True
# 9047         Merged                    True
#
# [3323 rows x 13 columns]

# %%
has_reviews[has_reviews['has_human_closing_user'] == False]
# Out:
#               id  number                       user    user_id  agent  \
# 326   2303153623   15991              renovate[bot]   29139614  Human
# 743   2437889808    4445                   pablonyx  171597620  Human
# 1532  2424036899    4038                    boxmoji   22225883  Human
# 1533  2364985069    3998                    boxmoji   22225883  Human
# 1534  2486762465    4079                    boxmoji   22225883  Human
# ...          ...     ...                        ...        ...    ...
# 8889  2903765641     355  devin-ai-integration[bot]  158243242  Devin
# 8931  2812399095   38849  devin-ai-integration[bot]  158243242  Devin
# 8934  2814227883   52583  devin-ai-integration[bot]  158243242  Devin
# 8976  2950313797     377  devin-ai-integration[bot]  158243242  Devin
# 9028  3007108786   20777  devin-ai-integration[bot]  158243242  Devin
#
#                                                repo_url  \
# 326           https://api.github.com/repos/grafana/loki
# 743      https://api.github.com/repos/onyx-dot-app/onyx
# 1532   https://api.github.com/repos/box/box-ui-elements
# 1533   https://api.github.com/repos/box/box-ui-elements
# 1534   https://api.github.com/repos/box/box-ui-elements
# ...                                                 ...
# 8889  https://api.github.com/repos/different-ai/note...
# 8931  https://api.github.com/repos/appsmithorg/appsmith
# 8934     https://api.github.com/repos/airbytehq/airbyte
# 8976  https://api.github.com/repos/different-ai/note...
# 9028        https://api.github.com/repos/calcom/cal.com
#
#                                                html_url  \
# 326          https://github.com/grafana/loki/pull/15991
# 743      https://github.com/onyx-dot-app/onyx/pull/4445
# 1532   https://github.com/box/box-ui-elements/pull/4038
# 1533   https://github.com/box/box-ui-elements/pull/3998
# 1534   https://github.com/box/box-ui-elements/pull/4079
# ...                                                 ...
# 8889  https://github.com/different-ai/note-companion...
# 8931  https://github.com/appsmithorg/appsmith/pull/3...
# 8934    https://github.com/airbytehq/airbyte/pull/52583
# 8976  https://github.com/different-ai/note-companion...
# 9028       https://github.com/calcom/cal.com/pull/20777
#
#                                             reviews_url  \
# 326   https://api.github.com/repos/grafana/loki/pull...
# 743   https://api.github.com/repos/onyx-dot-app/onyx...
# 1532  https://api.github.com/repos/box/box-ui-elemen...
# 1533  https://api.github.com/repos/box/box-ui-elemen...
# 1534  https://api.github.com/repos/box/box-ui-elemen...
# ...                                                 ...
# 8889  https://api.github.com/repos/different-ai/note...
# 8931  https://api.github.com/repos/appsmithorg/appsm...
# 8934  https://api.github.com/repos/airbytehq/airbyte...
# 8976  https://api.github.com/repos/different-ai/note...
# 9028  https://api.github.com/repos/calcom/cal.com/pu...
#
#                                            reviews_data  \
# 326   [{'user': 'renovate-approve[bot]', 'state': 'A...
# 743   [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 1532  [{'user': 'greg-in-a-box', 'state': 'APPROVED'...
# 1533  [{'user': 'greg-in-a-box', 'state': 'APPROVED'...
# 1534  [{'user': 'greg-in-a-box', 'state': 'APPROVED'...
# ...                                                 ...
# 8889  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 8931  [{'user': 'KelvinOm', 'state': 'COMMENTED', 'b...
# 8934  [{'user': 'aaronsteers', 'state': 'COMMENTED',...
# 8976  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 9028  [{'user': 'PeerRich', 'state': 'DISMISSED', 'b...
#
#                                       review_counts_map  \
# 326                        {'renovate-approve[bot]': 1}
# 743                           {'greptile-apps[bot]': 1}
# 1532                               {'greg-in-a-box': 1}
# 1533                               {'greg-in-a-box': 1}
# 1534                               {'greg-in-a-box': 1}
# ...                                                 ...
# 8889                          {'greptile-apps[bot]': 1}
# 8931                                    {'KelvinOm': 1}
# 8934                                 {'aaronsteers': 1}
# 8976                          {'greptile-apps[bot]': 1}
# 9028  {'PeerRich': 1, 'cubic-dev-ai[bot]': 1, 'Tusha...
#
#                  closed_by_user closing_method  has_human_closing_user
# 326               renovate[bot]         Merged                   False
# 743         github-actions[bot]         Closed                   False
# 1532               mergify[bot]         Merged                   False
# 1533               mergify[bot]         Merged                   False
# 1534               mergify[bot]         Merged                   False
# ...                         ...            ...                     ...
# 8889  devin-ai-integration[bot]         Closed                   False
# 8931  devin-ai-integration[bot]         Closed                   False
# 8934  devin-ai-integration[bot]         Closed                   False
# 8976  devin-ai-integration[bot]         Closed                   False
# 9028  devin-ai-integration[bot]         Closed                   False
#
# [105 rows x 13 columns]

# %%
# Se quiser salvar:
has_reviews.to_parquet(r'output_files\prs_reviews.parquet', index=False)
