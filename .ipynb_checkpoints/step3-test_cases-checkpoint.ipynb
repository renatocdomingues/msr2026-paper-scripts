# %%
import ast
import numpy as np
import pandas as pd
import re
import json
import os

# %%
prs = pd.read_parquet(r'output_files\fix_prs_with_issues_and_files.parquet')
prs
# Out:
#               id  number                       user    user_id  agent  \
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 1     2265431531   83085                ArthurKnaus    7033940  Human
# 2     2622011651   94465                     bukzor     640328  Human
# 3     2565399631   92785                     dashed     139499  Human
# 4     2374801945   86438             brendanhsentry  171613822  Human
# ...          ...     ...                        ...        ...    ...
# 9879  3260452571    1542  devin-ai-integration[bot]  158243242  Devin
# 9880  2857103111    2151  devin-ai-integration[bot]  158243242  Devin
# 9881  2857279950    8459  devin-ai-integration[bot]  158243242  Devin
# 9882  2857942945       2  devin-ai-integration[bot]  158243242  Devin
# 9883  2858280902     775  devin-ai-integration[bot]  158243242  Devin
#
#                                                   title  \
# 0     :bug: fix: update how we fetch workflow_id and...
# 1            fix(org-stats): Require project membership
# 2             fix(dev): mktemp: too few X's in template
# 3     fix(billing): Update calculateCategoryPrepaidU...
# 4                    fix: copy updates to checkout page
# ...                                                 ...
# 9879        Fix CSS color assertions in test_lambdas.py
# 9880   fix: Initialize storage in StringKnowledgeSource
# 9881   Add missing OpenSSL TLSEXT status response codes
# 9882  fix: improve dark mode input focus and toggle ...
# 9883           Fix heap buffer overflow in BundlePacket
#
#                                                    body   state  \
# 0     i realized i made a mistake for how i fetch th...  closed
# 1     ### Problem\r\n\r\nIf the user is not member o...  closed
# 2     For maximum compatibility, busybox mktemp requ...  closed
# 3     Closes https://linear.app/getsentry/issue/BIL-...  closed
# 4     closes https://github.com/getsentry/getsentry/...  closed
# ...                                                 ...     ...
# 9879  # Fix CSS color assertions in test_lambdas.py\...  closed
# 9880  Fixes #2150\n\n## Issue\nStringKnowledgeSource...  closed
# 9881  Fixes the build failure in the OpenSSL coexist...  closed
# 9882  # UI Improvements: Dark Mode Input Focus and T...  closed
# 9883  This PR fixes a heap buffer overflow in Bundle...  closed
#
#                 created_at             closed_at             merged_at  \
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  2025-04-04T15:10:57Z
# 1     2025-01-08T07:47:13Z  2025-01-08T08:49:40Z  2025-01-08T08:49:40Z
# 2     2025-06-26T18:54:10Z  2025-06-26T19:57:23Z  2025-06-26T19:57:23Z
# 3     2025-06-03T22:22:51Z  2025-06-05T18:13:54Z  2025-06-05T18:13:54Z
# 4     2025-03-05T22:39:12Z  2025-03-06T16:57:20Z  2025-03-06T16:57:20Z
# ...                    ...                   ...                   ...
# 9879  2025-07-24T16:14:38Z  2025-07-25T11:29:31Z  2025-07-25T11:29:31Z
# 9880  2025-02-17T08:16:22Z  2025-02-25T16:39:20Z                  None
# 9881  2025-02-17T09:32:13Z  2025-02-17T09:34:11Z                  None
# 9882  2025-02-17T13:57:22Z  2025-02-17T14:40:12Z  2025-02-17T14:40:12Z
# 9883  2025-02-17T16:15:35Z  2025-02-17T16:23:53Z                  None
#
#                                                repo_url  \
# 0         https://api.github.com/repos/getsentry/sentry
# 1         https://api.github.com/repos/getsentry/sentry
# 2         https://api.github.com/repos/getsentry/sentry
# 3         https://api.github.com/repos/getsentry/sentry
# 4         https://api.github.com/repos/getsentry/sentry
# ...                                                 ...
# 9879  https://api.github.com/repos/reflex-dev/reflex...
# 9880      https://api.github.com/repos/crewAIInc/crewAI
# 9881       https://api.github.com/repos/wolfSSL/wolfssl
# 9882  https://api.github.com/repos/jina-ai/deepsearc...
# 9883       https://api.github.com/repos/wolfSSL/wolfssh
#
#                                                html_url   issues  has_issues  \
# 0        https://github.com/getsentry/sentry/pull/88748       []       False
# 1        https://github.com/getsentry/sentry/pull/83085  [82998]        True
# 2        https://github.com/getsentry/sentry/pull/94465       []       False
# 3        https://github.com/getsentry/sentry/pull/92785       []       False
# 4        https://github.com/getsentry/sentry/pull/86438       []       False
# ...                                                 ...      ...         ...
# 9879  https://github.com/reflex-dev/reflex-web/pull/...       []       False
# 9880      https://github.com/crewAIInc/crewAI/pull/2151   [2150]        True
# 9881       https://github.com/wolfSSL/wolfssl/pull/8459       []       False
# 9882    https://github.com/jina-ai/deepsearch-ui/pull/2       []       False
# 9883        https://github.com/wolfSSL/wolfssh/pull/775       []       False
#
#                                          modified_files
# 0     [{"filename": "src/sentry/integrations/opsgeni...
# 1     [{"filename": "static/app/views/organizationSt...
# 2     [{"filename": ".envrc", "status": "modified", ...
# 3     [{"filename": "static/gsApp/views/subscription...
# 4     [{"filename": "static/gsApp/views/amCheckout/s...
# ...                                                 ...
# 9879  [{"filename": "tests/test_lambdas.py", "status...
# 9880  [{"filename": "src/crewai/knowledge/source/str...
# 9881  [{"filename": "wolfssl/openssl/ssl.h", "status...
# 9882  [{"filename": "app.js", "status": "modified", ...
# 9883  [{"filename": "src/internal.c", "status": "mod...
#
# [9884 rows x 16 columns]

# %%
def remover_patch_e_converter(item):
    """
    Remove o campo "patch" (que está corrompido) da string 
    e depois a converte para uma lista.
    """
    if not isinstance(item, str):
        return item
    
    item_limpo = item.strip()
    if item_limpo == "":
        return []

    # --- O PASSO MAIS IMPORTANTE ---
    # Este regex encontra "patch": null OU "patch": "..."
    # e lida corretamente com aspas escapadas (\"...\") dentro do patch.
    # Ele substitui o campo por "patch": null, que é seguro de analisar.
    
    # Regex para encontrar "patch": "..." (lidando com escapes)
    regex_string_patch = r'"patch":\s*"(?:[^"\\]|\\.)*"'
    # Regex para encontrar "patch": null
    regex_null_patch = r'"patch":\s*null'
    
    # Combina os dois:
    regex_full = f"({regex_string_patch}|{regex_null_patch})"
    
    # Substitui o que foi encontrado por um valor inofensivo
    item_sem_patch = re.sub(regex_full, '"patch": null', item_limpo)
    
    # --- AGORA, A CONVERSÃO (que já tentamos antes) ---
    # Mas agora vai funcionar, pois a string está limpa.
    
    # 1. Corrigir literais Python -> JSON
    item_corrigido = re.sub(r'\bNone\b', 'null', item_sem_patch, flags=re.IGNORECASE)
    item_corrigido = re.sub(r'\bTrue\b', 'true', item_corrigido, flags=re.IGNORECASE)
    item_corrigido = re.sub(r'\bFalse\b', 'false', item_corrigido, flags=re.IGNORECASE)
    item_corrigido = re.sub(r'\bnan\b', 'null', item_corrigido, flags=re.IGNORECASE)

    # 2. Tentar decodificar como JSON
    try:
        return json.loads(item_corrigido)
    except json.JSONDecodeError as e:
        # Se falhar mesmo sem o patch, a string está 100% perdida
        return np.nan

# %%
def converter_para_lista_json_robusta(item):
    """
    Converte uma string (JSON-like) para uma lista.
    Lida com literais Python (None, True, nan) que podem estar misturados.
    Retorna np.nan se a string estiver 100% corrompida.
    """
    # 1. Se não for uma string (já é lista, ou NaN real), apenas retorne
    if not isinstance(item, str):
        return item
    
    # 2. Se for uma string, primeiro remova espaços em branco
    item_limpo = item.strip()
    
    # 3. Se for uma string vazia, retorne uma lista vazia []
    if item_limpo == "":
        return []
        
    # --- ETAPA DE CORREÇÃO (Python -> JSON) ---
    item_corrigido = re.sub(r'\bNone\b', 'null', item_limpo, flags=re.IGNORECASE)
    item_corrigido = re.sub(r'\bTrue\b', 'true', item_corrigido, flags=re.IGNORECASE)
    item_corrigido = re.sub(r'\bFalse\b', 'false', item_corrigido, flags=re.IGNORECASE)
    item_corrigido = re.sub(r'\bnan\b', 'null', item_corrigido, flags=re.IGNORECASE)
    item_corrigido = re.sub(r'\binf\b', 'null', item_corrigido, flags=re.IGNORECASE)
    item_corrigido = re.sub(r'\b-inf\b', 'null', item_corrigido, flags=re.IGNORECASE)

    # 4. Tente decodificar como JSON
    try:
        return json.loads(item_corrigido)
    except json.JSONDecodeError as e:
        # Aqui é onde as 144 linhas corrompidas (com patch) vão cair
        return np.nan # Retorna NaN

# %%
prs['modified_files_list'] = prs['modified_files'].apply(converter_para_lista_json_robusta)
# --- PASSO 1: Fazer o explode() ---
# Agora o explode vai funcionar na coluna nova!
df_exploded = prs.explode('modified_files_list')
#display(df_exploded)
# --- PASSO 2: Normalizar (expandir o dict) ---
# Use pd.json_normalize para expandir os dicionários em colunas.
# É a forma mais robusta.
# Precisamos realinhar o índice, pois json_normalize zera ele.
normalized_cols = pd.json_normalize(df_exploded['modified_files_list'])
normalized_cols.index = df_exploded.index

# --- PASSO 3: Juntar tudo ---
# Juntamos as colunas originais (exceto as de lista) com as novas colunas
prs_and_changes = pd.concat(
    [df_exploded.drop(['modified_files'], axis=1), normalized_cols],
    axis=1
)
prs_and_changes
# Out:
#               id  number                       user    user_id  agent  \
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 1     2265431531   83085                ArthurKnaus    7033940  Human
# ...          ...     ...                        ...        ...    ...
# 9880  2857103111    2151  devin-ai-integration[bot]  158243242  Devin
# 9881  2857279950    8459  devin-ai-integration[bot]  158243242  Devin
# 9882  2857942945       2  devin-ai-integration[bot]  158243242  Devin
# 9882  2857942945       2  devin-ai-integration[bot]  158243242  Devin
# 9883  2858280902     775  devin-ai-integration[bot]  158243242  Devin
#
#                                                   title  \
# 0     :bug: fix: update how we fetch workflow_id and...
# 0     :bug: fix: update how we fetch workflow_id and...
# 0     :bug: fix: update how we fetch workflow_id and...
# 0     :bug: fix: update how we fetch workflow_id and...
# 1            fix(org-stats): Require project membership
# ...                                                 ...
# 9880   fix: Initialize storage in StringKnowledgeSource
# 9881   Add missing OpenSSL TLSEXT status response codes
# 9882  fix: improve dark mode input focus and toggle ...
# 9882  fix: improve dark mode input focus and toggle ...
# 9883           Fix heap buffer overflow in BundlePacket
#
#                                                    body   state  \
# 0     i realized i made a mistake for how i fetch th...  closed
# 0     i realized i made a mistake for how i fetch th...  closed
# 0     i realized i made a mistake for how i fetch th...  closed
# 0     i realized i made a mistake for how i fetch th...  closed
# 1     ### Problem\r\n\r\nIf the user is not member o...  closed
# ...                                                 ...     ...
# 9880  Fixes #2150\n\n## Issue\nStringKnowledgeSource...  closed
# 9881  Fixes the build failure in the OpenSSL coexist...  closed
# 9882  # UI Improvements: Dark Mode Input Focus and T...  closed
# 9882  # UI Improvements: Dark Mode Input Focus and T...  closed
# 9883  This PR fixes a heap buffer overflow in Bundle...  closed
#
#                 created_at             closed_at  ...  \
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  ...
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  ...
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  ...
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  ...
# 1     2025-01-08T07:47:13Z  2025-01-08T08:49:40Z  ...
# ...                    ...                   ...  ...
# 9880  2025-02-17T08:16:22Z  2025-02-25T16:39:20Z  ...
# 9881  2025-02-17T09:32:13Z  2025-02-17T09:34:11Z  ...
# 9882  2025-02-17T13:57:22Z  2025-02-17T14:40:12Z  ...
# 9882  2025-02-17T13:57:22Z  2025-02-17T14:40:12Z  ...
# 9883  2025-02-17T16:15:35Z  2025-02-17T16:23:53Z  ...
#
#                                              html_url   issues has_issues  \
# 0      https://github.com/getsentry/sentry/pull/88748       []      False
# 0      https://github.com/getsentry/sentry/pull/88748       []      False
# 0      https://github.com/getsentry/sentry/pull/88748       []      False
# 0      https://github.com/getsentry/sentry/pull/88748       []      False
# 1      https://github.com/getsentry/sentry/pull/83085  [82998]       True
# ...                                               ...      ...        ...
# 9880    https://github.com/crewAIInc/crewAI/pull/2151   [2150]       True
# 9881     https://github.com/wolfSSL/wolfssl/pull/8459       []      False
# 9882  https://github.com/jina-ai/deepsearch-ui/pull/2       []      False
# 9882  https://github.com/jina-ai/deepsearch-ui/pull/2       []      False
# 9883      https://github.com/wolfSSL/wolfssh/pull/775       []      False
#
#                                     modified_files_list  \
# 0     {'filename': 'src/sentry/integrations/opsgenie...
# 0     {'filename': 'src/sentry/notifications/notific...
# 0     {'filename': 'src/sentry/notifications/utils/l...
# 0     {'filename': 'tests/sentry/integrations/opsgen...
# 1     {'filename': 'static/app/views/organizationSta...
# ...                                                 ...
# 9880  {'filename': 'tests/knowledge/knowledge_test.p...
# 9881  {'filename': 'wolfssl/openssl/ssl.h', 'status'...
# 9882  {'filename': 'app.js', 'status': 'modified', '...
# 9882  {'filename': 'styles.css', 'status': 'modified...
# 9883  {'filename': 'src/internal.c', 'status': 'modi...
#
#                                                filename    status additions  \
# 0            src/sentry/integrations/opsgenie/client.py  modified       3.0
# 0       src/sentry/notifications/notifications/rules.py  modified       5.0
# 0               src/sentry/notifications/utils/links.py  modified       1.0
# 0     tests/sentry/integrations/opsgenie/test_client.py  modified      15.0
# 1     static/app/views/organizationStats/index.spec.tsx  modified      29.0
# ...                                                 ...       ...       ...
# 9880                  tests/knowledge/knowledge_test.py  modified      40.0
# 9881                              wolfssl/openssl/ssl.h  modified       5.0
# 9882                                             app.js  modified      10.0
# 9882                                         styles.css  modified      45.0
# 9883                                     src/internal.c  modified      12.0
#
#      deletions  changes                                              patch
# 0          2.0      5.0  @@ -10,6 +10,7 @@\n from sentry.integrations.o...
# 0          0.0      5.0  @@ -19,6 +19,7 @@\n     ProfileFunctionRegress...
# 0          1.0      2.0  @@ -5,7 +5,7 @@\n """\n \n \n-def create_link_...
# 0          5.0     20.0  @@ -133,8 +133,12 @@ def test_send_notificatio...
# 1          0.0     29.0  @@ -498,6 +498,35 @@ describe('OrganizationSta...
# ...        ...      ...                                                ...
# 9880       0.0     40.0  @@ -5,6 +5,7 @@\n from unittest.mock import pa...
# 9881       0.0      5.0  @@ -115,6 +115,11 @@\n \n #define WOLFSSL_TLSE...
# 9882       7.0     17.0  @@ -15,7 +15,8 @@ const UI_STRINGS = {\n     }...
# 9882       5.0     50.0  @@ -10,6 +10,7 @@\n     --text-secondary: #5f6...
# 9883       2.0     14.0  @@ -10057,7 +10057,11 @@ static int PreparePac...
#
# [66242 rows x 22 columns]

# %%
# --- 1. REGEX PARA IDENTIFICAR ARQUIVOS DE TESTE ---
# (Corrigido: '(?_tests__' -> '(?:__tests__')
filename_regex = (
    r'('
    r'(?:^tests[/\\])'                     # começa com tests/
    r'|(?:[/\\]tests?[/\\])'               # contém /tests/ ou /test/
    r'|(?:[/\\]test[/\\])'                 # contém /test/
    r'|(?:__tests__[/\\])'                 # __tests__/  <-- AQUI ESTÁ A CORREÇÃO
    r'|(?:\.spec\b)'                       # .spec (ex: index.spec.tsx)
    r'|(?:\_test\.)'                       # _test. (ex: foo_test.py)
    r'|(?:\.test\.)'                       # .test. (ex: utils.test.js)
    r'|(?:src[/\\]test[/\\])'              # src/test/ (Java/Kotlin)
    r'|(?:[/\\](?:unit[-_]?tests?|integration[-_]?tests?)[/\\])' # /unit-tests/
    r'|(?:\_spec\.)'                       # _spec. (Ruby, etc.)
    r'|(?:[A-Za-z0-9_]+(?:Test|Tests|Spec)\.[a-z0-9]+$)' # NameTest.ext
    r'|(?:Test\.(?:php|java|cs|kt|ts|tsx|py|go|rb))'  # Test.php, Test.java, ...
    r')'
)

# --- 2. REGEX PARA IGNORAR ARQUIVOS DE CONFIG/LOCK/DOCS ---
config_regex = (
    r'('
    # 1. Arquivos de lock e dependência (nomes exatos no final da string)
    r'(?:package-lock\.json$|yarn\.lock$|composer\.lock$|requirements\.txt$)'
    
    # 2. Extensões comuns de config, dados ou documentação
    r'|(?:\.(json|ya?ml|xml|ini|toml|conf(ig)?|lock|log|md|txt)$)'
    
    # 3. Dotfiles (arquivos que começam com ., ex: .gitignore, .prettierrc)
    r'|([/\\]\.[^/\\]+$)'
    r')'
)


# --- 3. APLICANDO A LÓGICA ---

# Passo 1: Marcar tudo que parece ser um teste
is_test_file = prs_and_changes['filename'].str.contains(
    filename_regex, 
    case=False,
    na=False
)

# Passo 2: Marcar tudo que é um arquivo de configuração/documentação
is_config_file = prs_and_changes['filename'].str.contains(
    config_regex, 
    case=False,
    na=False
)

# Passo 3: A regra final.
prs_and_changes['is_filename_a_test_file'] = is_test_file
prs_and_changes['is_filename_a_config_file'] = is_config_file
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10748\262723971.py:38: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   is_test_file = prs_and_changes['filename'].str.contains(
# C:\Users\USER\AppData\Local\Temp\ipykernel_10748\262723971.py:45: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   is_config_file = prs_and_changes['filename'].str.contains(

# %%
content_pattern = re.compile(
    r'(def\s+test_|pytest\b|unittest\b|assert\b|describe\s*\(|\bit\s*\(|\btest\(|\bexpect\(|@Test\b|func\s+Test\b)',
    re.IGNORECASE
)
def is_test_by_content(patch):
    # 1. Checa por não-strings:
    #    - pd.isna() pega None e np.nan
    #    - not isinstance(patch, str) pega números, listas, etc.
    if pd.isna(patch) or not isinstance(patch, str):
        return False
    
    # 2. Checa por strings vazias (que o 'not patch' fazia)
    if not patch:
        return False
        
    # 3. Se for uma string válida, faça a busca
    return bool(content_pattern.search(patch))

# --- APLICAÇÃO CORRIGIDA ---
# Remova o .fillna('') - a função agora cuida de tudo.
prs_and_changes['is_patch_a_test_file'] = prs_and_changes['patch'].apply(is_test_by_content)

# %%
prs_and_changes['is_test_file'] = ~prs_and_changes['is_filename_a_config_file'] & \
(prs_and_changes['is_filename_a_test_file'] | prs_and_changes['is_patch_a_test_file'])


# Opcional: ver quantos foram detectados por cada heurística
print('Total Files:',len(prs_and_changes))
print("Config file identified by name:", prs_and_changes['is_filename_a_config_file'].sum())
print("Contagem de arquivos de teste (excluindo configs):")
print("Test identified by name:", prs_and_changes['is_filename_a_test_file'].sum())

print("Test identified by patch:", prs_and_changes['is_patch_a_test_file'].sum(),'<- Ta gerando Falso Positivos, é pra manter mesmo?')

print("Combined:", prs_and_changes['is_test_file'].sum())
# Out:
# Total Files: 66242
# Config file identified by name: 9164
# Contagem de arquivos de teste (excluindo configs):
# Test identified by name: 19634
# Test identified by patch: 6065 <- Ta gerando Falso Positivos, é pra manter mesmo?
# Combined: 20019

# %%
prs_and_changes[prs_and_changes['is_test_file'] == True].groupby(['id','number','repo_url','status'])\
                                                                            .count().reset_index()\
                                                                            [['id','number','repo_url','status','user']]
# Out:
#               id  number                                           repo_url  \
# 0     2257049791     983  https://api.github.com/repos/OpenHFT/Chronicle...
# 1     2257049791     983  https://api.github.com/repos/OpenHFT/Chronicle...
# 2     2257440492    2770       https://api.github.com/repos/wechaty/wechaty
# 3     2257617018   11748  https://api.github.com/repos/microsoft/azurelinux
# 4     2257823162    1007        https://api.github.com/repos/julep-ai/julep
# ...          ...     ...                                                ...
# 4621  3277858730   15128       https://api.github.com/repos/mochilang/mochi
# 4622  3277873389   15132       https://api.github.com/repos/mochilang/mochi
# 4623  3277873389   15132       https://api.github.com/repos/mochilang/mochi
# 4624  3277943226    1730  https://api.github.com/repos/freenet/freenet-core
# 4625  3277956035   15142       https://api.github.com/repos/mochilang/mochi
#
#         status  user
# 0        added     1
# 1     modified     1
# 2     modified     1
# 3     modified     1
# 4     modified     2
# ...        ...   ...
# 4621     added    14
# 4622     added   127
# 4623  modified    21
# 4624  modified     1
# 4625     added     3
#
# [4626 rows x 5 columns]

# %%
number_of_tests = prs_and_changes[prs_and_changes['is_test_file'] == True].groupby(['id','number','repo_url','status'])\
                                                                            .count().reset_index()\
                                                                            [['id','number','repo_url','status','user']]
number_of_tests.rename(columns={"user": "quantity"},inplace = True)
number_of_tests.sort_values('quantity')
prs['#_of_files'] = prs['modified_files_list'].str.len()

# 1. Use pivot_table para fazer a transformação
pivoted_number_of_tests = number_of_tests.pivot_table(
    index=['id', 'number', 'repo_url'],  # Colunas que identificam a linha
    columns='status',                   # Coluna cujos valores virarão novas colunas
    values='quantity',                  # Coluna cujos valores irão preencher as células
    aggfunc='sum',                      # O que fazer se houver duplicatas (somar)
    fill_value=0                        # Substituir NaNs por 0
)

# 2. Adicione o sufixo '_tests' aos novos nomes de coluna (x, y, z)
pivoted_number_of_tests = pivoted_number_of_tests.add_suffix('_tests')

# 3. Limpeza: 'achatar' o índice de colunas e trazer o índice de volta
df_final = pivoted_number_of_tests.rename_axis(columns=None).reset_index()

# 1. Faça o merge. Isso criará o DataFrame com NaNs
merged_df = pd.merge(prs, df_final, on=['id', 'number', 'repo_url'], how='left')

# 2. Preencha os NaNs com 0 APENAS na(s) coluna(s) específica(s)
# (Troque 'nome_da_coluna_de_contagem' pelo nome real da sua coluna)
merged_df[['added_tests','modified_tests','removed_tests','renamed_tests']] = merged_df[['added_tests','modified_tests',
                                                                                                     'removed_tests','renamed_tests']].fillna(0)

# (Opcional) Se você quiser que a coluna seja de inteiros (em vez de float 6.0)
merged_df[['added_tests','modified_tests','removed_tests','renamed_tests']] = merged_df[['added_tests','modified_tests',
                                                                                                     'removed_tests','renamed_tests']].astype(int)
prs_with_files = merged_df[merged_df['#_of_files'] > 0]
prs_without_files = merged_df[merged_df['#_of_files'] == 0]

colunas_de_teste = ['added_tests', 'modified_tests', 'removed_tests']

# 1. Soma as colunas (trata NaNs como 0)
soma_testes = merged_df[colunas_de_teste].sum(axis=1)

# 2. Cria a coluna final (True se a soma for maior que 0)
merged_df['has_modified_test'] = (soma_testes > 0)

merged_df.to_parquet(r'output_files\fix_prs_with_issues_and_files_and_tests.parquet')
merged_df.sort_values('#_of_files')
# Out:
#               id  number          user    user_id         agent  \
# 5863  3073705436    1411  HamadaSalhab   31417987  OpenAI_Codex
# 5532  3254229539       4     DragonJAR   28887492  OpenAI_Codex
# 5544  3206635286   13715    buddhika75    1226946  OpenAI_Codex
# 6252  3253444677       3     DragonJAR   28887492  OpenAI_Codex
# 6400  3131643166    7888     stephanos     159852  OpenAI_Codex
# ...          ...     ...           ...        ...           ...
# 829   2441723793     382       Makisuo   31933546         Human
# 3210  3161009617    7058       Copilot  198982749       Copilot
# 219   2522536730    1841     drfarrell   14104075         Human
# 3857  3259062672     394       Copilot  198982749       Copilot
# 2766  3076780891    2007       Copilot  198982749       Copilot
#
#                                                   title  \
# 5863           Fix isinstance union usage in agents-api
# 5532                               Fix complexity label
# 5544           Fix ampersand text in pharmacy analytics
# 6252                              Fix complexity levels
# 6400                           Fix multiop update retry
# ...                                                 ...
# 829                                         Fix example
# 3210  Fix RMSNormalization Range inputs to comply wi...
# 219   Styling improvements to the editor + projects ...
# 3857  [WIP] Please analyze the proposed new test cas...
# 2766  Make anchor links in Git's documentation backw...
#
#                                                    body   state  \
# 5863  ### **User description**\n## Summary\n- fix is...  closed
# 5532  ## Summary\n- update lines labelled `Media (1 ...  closed
# 5544  ## Summary\n- fix "andamp" and other ampersand...  closed
# 6252  ## Summary\n- fix complexity labels in README ...  closed
# 6400  ## Summary\n- retry multioperation if update c...  closed
# ...                                                 ...     ...
# 829                                                None  closed
# 3210  The RMSNormalization operator's function body ...  closed
# 219   ## Description\r\n\r\n* Styling improvements t...  closed
# 3857  - [x] Analyze the repository structure and und...  closed
# 2766  ## Summary\nThis PR fixes an issue where ancho...  closed
#
#                 created_at             closed_at  ...  issues has_issues  \
# 5863  2025-05-19T12:39:32Z  2025-06-07T07:34:34Z  ...      []      False
# 5532  2025-07-22T22:14:24Z  2025-07-22T22:14:56Z  ...      []      False
# 5544  2025-07-06T14:46:42Z  2025-07-06T14:46:55Z  ...      []      False
# 6252  2025-07-22T17:06:45Z  2025-07-22T17:07:03Z  ...      []      False
# 6400  2025-06-09T22:33:21Z  2025-06-12T15:58:34Z  ...      []      False
# ...                    ...                   ...  ...     ...        ...
# 829   2025-04-06T15:58:36Z  2025-04-06T16:05:50Z  ...      []      False
# 3210  2025-06-19T17:48:50Z  2025-07-16T19:11:47Z  ...  [7054]       True
# 219   2025-05-15T15:55:01Z  2025-05-15T23:42:41Z  ...      []      False
# 3857  2025-07-24T08:50:17Z  2025-07-24T09:03:34Z  ...      []      False
# 2766  2025-05-20T12:03:47Z  2025-05-23T14:29:20Z  ...  [2002]       True
#
#                                          modified_files  \
# 5863                                                 []
# 5532                                                 []
# 5544                                                 []
# 6252                                                 []
# 6400                                                 []
# ...                                                 ...
# 829   [{"filename": ".gitignore", "status": "modifie...
# 3210  [{"filename": ".gitignore", "status": "removed...
# 219   [{"filename": ".gitignore", "status": "modifie...
# 3857  [{"filename": ".gitignore", "status": "modifie...
# 2766  [{"filename": "assets/js/application.js", "sta...
#
#                                     modified_files_list  #_of_files  \
# 5863                                                 []           0
# 5532                                                 []           0
# 5544                                                 []           0
# 6252                                                 []           0
# 6400                                                 []           0
# ...                                                 ...         ...
# 829   [{'filename': '.gitignore', 'status': 'modifie...         770
# 3210  [{'filename': '.gitignore', 'status': 'removed...        1026
# 219   [{'filename': '.gitignore', 'status': 'modifie...        1171
# 3857  [{'filename': '.gitignore', 'status': 'modifie...        3000
# 2766  [{'filename': 'assets/js/application.js', 'sta...        3000
#
#      added_tests modified_tests  removed_tests  renamed_tests  \
# 5863           0              0              0              0
# 5532           0              0              0              0
# 5544           0              0              0              0
# 6252           0              0              0              0
# 6400           0              0              0              0
# ...          ...            ...            ...            ...
# 829            0              0              0              0
# 3210         410              0              0              0
# 219           16              4             29              0
# 3857        1160              1              0              0
# 2766           1             29              0              0
#
#       has_modified_test
# 5863              False
# 5532              False
# 5544              False
# 6252              False
# 6400              False
# ...                 ...
# 829               False
# 3210               True
# 219                True
# 3857               True
# 2766               True
#
# [9884 rows x 23 columns]

# %%
prs_with_test_list = prs_and_changes[prs_and_changes['is_test_file'] == True]['id'].unique().tolist()
prs_with_identified_test = prs[prs['id'].isin(prs_with_test_list)]
prs_without_identified_test = prs[~prs['id'].isin(prs_with_test_list)]
print('Total de PRs & fix & issues:',len(prs))
print('Total de PRs com files:',len(prs_with_files))
print("Total de PRs sem files:", len(prs_without_files))
print('Total de PRs de fix & issues & tests:',len(prs_with_identified_test))
print("Total de PRs de fix & issues & ~tests:", len(prs_without_identified_test))
# Out:
# Total de PRs & fix & issues: 9884
# Total de PRs com files: 9663
# Total de PRs sem files: 221
# Total de PRs de fix & issues & tests: 3816
# Total de PRs de fix & issues & ~tests: 6068

# %%
prs_with_identified_test[prs_with_identified_test['agent'] != 'Human']
# Out:
#               id  number                       user    user_id        agent  \
# 1778  3264933329    2911                 weiliu1031  108661493  Claude_Code
# 1779  3212961701     113                     ruvnet    2934394  Claude_Code
# 1780  3214876564    5490                    wtfsayo   82053242  Claude_Code
# 1781  3215730319  157910                    soumith    1310570  Claude_Code
# 1788  3271748860    1727                     sanity      23075  Claude_Code
# ...          ...     ...                        ...        ...          ...
# 9872  3275147252     710  devin-ai-integration[bot]  158243242        Devin
# 9873  3275195929    3237  devin-ai-integration[bot]  158243242        Devin
# 9874  3275218917    1885  devin-ai-integration[bot]  158243242        Devin
# 9879  3260452571    1542  devin-ai-integration[bot]  158243242        Devin
# 9880  2857103111    2151  devin-ai-integration[bot]  158243242        Devin
#
#                                                   title  \
# 1778  Fix: Wait for all partitions in load_collectio...
# 1779  fix: Add missing logger.js and resolve MCP ser...
# 1780  fix: critical issues in action chaining implem...
# 1781  Fix logdet returning finite values for singula...
# 1788  fix: handle PUT/UPDATE operations when gateway...
# ...                                                 ...
# 9872  Allow decimal values in Search Purchase charge...
# 9873    Fix Windows path length issue in memory storage
# 9874     Add database fallback to crawl errors endpoint
# 9879        Fix CSS color assertions in test_lambdas.py
# 9880   fix: Initialize storage in StringKnowledgeSource
#
#                                                    body   state  \
# 1778  ## Summary\n\nFixes an issue where `load_colle...  closed
# 1779  ## Summary\n\nFixed critical MCP server issues...  closed
# 1780  ## Summary\n\nThis PR addresses all critical i...  closed
# 1781  Fixes https://github.com/pytorch/pytorch/issue...    open
# 1788  ## Description\n\nWhen a gateway has no connec...  closed
# ...                                                 ...     ...
# 9872  # Allow decimal values in Search Purchase char...    open
# 9873  # Fix Windows path length issue in memory stor...    open
# 9874  # Add database fallback to crawl errors endpoi...    open
# 9879  # Fix CSS color assertions in test_lambdas.py\...  closed
# 9880  Fixes #2150\n\n## Issue\nStringKnowledgeSource...  closed
#
#                 created_at             closed_at             merged_at  \
# 1778  2025-07-26T02:59:01Z  2025-07-29T07:01:20Z                  None
# 1779  2025-07-08T15:26:38Z  2025-07-08T15:27:58Z                  None
# 1780  2025-07-09T07:39:31Z  2025-07-09T08:35:49Z  2025-07-09T08:35:49Z
# 1781  2025-07-09T12:13:49Z                  None                  None
# 1788  2025-07-29T02:33:02Z  2025-07-29T23:22:04Z  2025-07-29T23:22:04Z
# ...                    ...                   ...                   ...
# 9872  2025-07-29T22:33:51Z                  None                  None
# 9873  2025-07-29T23:01:35Z                  None                  None
# 9874  2025-07-29T23:16:08Z                  None                  None
# 9879  2025-07-24T16:14:38Z  2025-07-25T11:29:31Z  2025-07-25T11:29:31Z
# 9880  2025-02-17T08:16:22Z  2025-02-25T16:39:20Z                  None
#
#                                                repo_url  \
# 1778    https://api.github.com/repos/milvus-io/pymilvus
# 1779       https://api.github.com/repos/ruvnet/ruv-FANN
# 1780         https://api.github.com/repos/elizaOS/eliza
# 1781       https://api.github.com/repos/pytorch/pytorch
# 1788  https://api.github.com/repos/freenet/freenet-core
# ...                                                 ...
# 9872      https://api.github.com/repos/antiwork/gumroad
# 9873      https://api.github.com/repos/crewAIInc/crewAI
# 9874  https://api.github.com/repos/mendableai/firecrawl
# 9879  https://api.github.com/repos/reflex-dev/reflex...
# 9880      https://api.github.com/repos/crewAIInc/crewAI
#
#                                                html_url    issues  has_issues  \
# 1778    https://github.com/milvus-io/pymilvus/pull/2911        []       False
# 1779        https://github.com/ruvnet/ruv-FANN/pull/113        []       False
# 1780         https://github.com/elizaOS/eliza/pull/5490        []       False
# 1781     https://github.com/pytorch/pytorch/pull/157910  [154312]        True
# 1788  https://github.com/freenet/freenet-core/pull/1727        []       False
# ...                                                 ...       ...         ...
# 9872       https://github.com/antiwork/gumroad/pull/710        []       False
# 9873      https://github.com/crewAIInc/crewAI/pull/3237    [3236]        True
# 9874  https://github.com/mendableai/firecrawl/pull/1885        []       False
# 9879  https://github.com/reflex-dev/reflex-web/pull/...        []       False
# 9880      https://github.com/crewAIInc/crewAI/pull/2151    [2150]        True
#
#                                          modified_files  \
# 1778  [{"filename": "pymilvus/client/async_grpc_hand...
# 1779  [{"filename": ".claude/commands/analysis/READM...
# 1780  [{"filename": "packages/core/src/__tests__/act...
# 1781  [{"filename": "aten/src/ATen/native/LinearAlge...
# 1788  [{"filename": "crates/core/src/operations/get....
# ...                                                 ...
# 9872  [{"filename": "app/services/admin_search_servi...
# 9873  [{"filename": "src/crewai/memory/storage/rag_s...
# 9874  [{"filename": "apps/api/src/__tests__/snips/cr...
# 9879  [{"filename": "tests/test_lambdas.py", "status...
# 9880  [{"filename": "src/crewai/knowledge/source/str...
#
#                                     modified_files_list  #_of_files
# 1778  [{'filename': 'pymilvus/client/async_grpc_hand...           3
# 1779  [{'filename': '.claude/commands/analysis/READM...         120
# 1780  [{'filename': 'packages/core/src/__tests__/act...           5
# 1781  [{'filename': 'aten/src/ATen/native/LinearAlge...           3
# 1788  [{'filename': 'crates/core/src/operations/get....           4
# ...                                                 ...         ...
# 9872  [{'filename': 'app/services/admin_search_servi...           2
# 9873  [{'filename': 'src/crewai/memory/storage/rag_s...           3
# 9874  [{'filename': 'apps/api/src/__tests__/snips/cr...           4
# 9879  [{'filename': 'tests/test_lambdas.py', 'status...           1
# 9880  [{'filename': 'src/crewai/knowledge/source/str...           2
#
# [3242 rows x 18 columns]

# %%
merged_df['modified_files_list'] = merged_df['modified_files'].apply(converter_para_lista_json_robusta)

def explode_df(merged_df):
    extensions_df_exploded = merged_df.explode('modified_files_list')
    extensions_normalized_cols = pd.json_normalize(extensions_df_exploded['modified_files_list'])
    extensions_normalized_cols.index = extensions_df_exploded.index
    to_be_extensions_df = pd.concat(
        [extensions_df_exploded.drop(['modified_files'], axis=1), extensions_normalized_cols],
        axis=1
    )
    return to_be_extensions_df
    
to_be_extensions_df = explode_df(merged_df)
to_be_extensions_df
# Out:
#               id  number                       user    user_id  agent  \
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 0     2438086945   88748                iamrajjoshi   33237075  Human
# 1     2265431531   83085                ArthurKnaus    7033940  Human
# ...          ...     ...                        ...        ...    ...
# 9880  2857103111    2151  devin-ai-integration[bot]  158243242  Devin
# 9881  2857279950    8459  devin-ai-integration[bot]  158243242  Devin
# 9882  2857942945       2  devin-ai-integration[bot]  158243242  Devin
# 9882  2857942945       2  devin-ai-integration[bot]  158243242  Devin
# 9883  2858280902     775  devin-ai-integration[bot]  158243242  Devin
#
#                                                   title  \
# 0     :bug: fix: update how we fetch workflow_id and...
# 0     :bug: fix: update how we fetch workflow_id and...
# 0     :bug: fix: update how we fetch workflow_id and...
# 0     :bug: fix: update how we fetch workflow_id and...
# 1            fix(org-stats): Require project membership
# ...                                                 ...
# 9880   fix: Initialize storage in StringKnowledgeSource
# 9881   Add missing OpenSSL TLSEXT status response codes
# 9882  fix: improve dark mode input focus and toggle ...
# 9882  fix: improve dark mode input focus and toggle ...
# 9883           Fix heap buffer overflow in BundlePacket
#
#                                                    body   state  \
# 0     i realized i made a mistake for how i fetch th...  closed
# 0     i realized i made a mistake for how i fetch th...  closed
# 0     i realized i made a mistake for how i fetch th...  closed
# 0     i realized i made a mistake for how i fetch th...  closed
# 1     ### Problem\r\n\r\nIf the user is not member o...  closed
# ...                                                 ...     ...
# 9880  Fixes #2150\n\n## Issue\nStringKnowledgeSource...  closed
# 9881  Fixes the build failure in the OpenSSL coexist...  closed
# 9882  # UI Improvements: Dark Mode Input Focus and T...  closed
# 9882  # UI Improvements: Dark Mode Input Focus and T...  closed
# 9883  This PR fixes a heap buffer overflow in Bundle...  closed
#
#                 created_at             closed_at  ... modified_tests  \
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  ...              2
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  ...              2
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  ...              2
# 0     2025-04-03T21:36:59Z  2025-04-04T15:10:57Z  ...              2
# 1     2025-01-08T07:47:13Z  2025-01-08T08:49:40Z  ...              1
# ...                    ...                   ...  ...            ...
# 9880  2025-02-17T08:16:22Z  2025-02-25T16:39:20Z  ...              1
# 9881  2025-02-17T09:32:13Z  2025-02-17T09:34:11Z  ...              0
# 9882  2025-02-17T13:57:22Z  2025-02-17T14:40:12Z  ...              0
# 9882  2025-02-17T13:57:22Z  2025-02-17T14:40:12Z  ...              0
# 9883  2025-02-17T16:15:35Z  2025-02-17T16:23:53Z  ...              0
#
#      removed_tests renamed_tests has_modified_test  \
# 0                0             0              True
# 0                0             0              True
# 0                0             0              True
# 0                0             0              True
# 1                0             0              True
# ...            ...           ...               ...
# 9880             0             0              True
# 9881             0             0             False
# 9882             0             0             False
# 9882             0             0             False
# 9883             0             0             False
#
#                                                filename    status  additions  \
# 0            src/sentry/integrations/opsgenie/client.py  modified        3.0
# 0       src/sentry/notifications/notifications/rules.py  modified        5.0
# 0               src/sentry/notifications/utils/links.py  modified        1.0
# 0     tests/sentry/integrations/opsgenie/test_client.py  modified       15.0
# 1     static/app/views/organizationStats/index.spec.tsx  modified       29.0
# ...                                                 ...       ...        ...
# 9880                  tests/knowledge/knowledge_test.py  modified       40.0
# 9881                              wolfssl/openssl/ssl.h  modified        5.0
# 9882                                             app.js  modified       10.0
# 9882                                         styles.css  modified       45.0
# 9883                                     src/internal.c  modified       12.0
#
#       deletions  changes                                              patch
# 0           2.0      5.0  @@ -10,6 +10,7 @@\n from sentry.integrations.o...
# 0           0.0      5.0  @@ -19,6 +19,7 @@\n     ProfileFunctionRegress...
# 0           1.0      2.0  @@ -5,7 +5,7 @@\n """\n \n \n-def create_link_...
# 0           5.0     20.0  @@ -133,8 +133,12 @@ def test_send_notificatio...
# 1           0.0     29.0  @@ -498,6 +498,35 @@ describe('OrganizationSta...
# ...         ...      ...                                                ...
# 9880        0.0     40.0  @@ -5,6 +5,7 @@\n from unittest.mock import pa...
# 9881        0.0      5.0  @@ -115,6 +115,11 @@\n \n #define WOLFSSL_TLSE...
# 9882        7.0     17.0  @@ -15,7 +15,8 @@ const UI_STRINGS = {\n     }...
# 9882        5.0     50.0  @@ -10,6 +10,7 @@\n     --text-secondary: #5f6...
# 9883        2.0     14.0  @@ -10057,7 +10057,11 @@ static int PreparePac...
#
# [66242 rows x 28 columns]

# %%
def extrair_extensao(caminho):
    # Checa se é uma string (ignora NaNs, Nones, etc.)
    if isinstance(caminho, str):
        # Pega a parte da extensão (ex: '.py')
        return os.path.splitext(caminho)[1]
    # Retorna nulo se a entrada não for uma string
    return None

def extensions_count(df):
    df['extensao'] = df['filename'].apply(extrair_extensao)
    extensions_count = df['extensao'].value_counts(dropna=False).reset_index()
    extensions_count.columns = ['extensao', 'count']
    extensions_count['extensao'] = extensions_count['extensao'].fillna('No file')
    extensions_count['extensao'] = extensions_count['extensao'].replace('', 'No extension')
    return extensions_count
extensions_count_fix = extensions_count(to_be_extensions_df)
extensions_count_fix.to_csv(r'output_files\files_extesions_count.csv',index = False)
extensions_count_fix
# Out:
#            extensao  count
# 0               .ts   8974
# 1               .py   6201
# 2              .tsx   4543
# 3               .md   3845
# 4             .html   3602
# ..              ...    ...
# 412         .output      1
# 413  .yaml_disabled      1
# 414            .pyw      1
# 415            .cob      1
# 416   .dockerignore      1
#
# [417 rows x 2 columns]

# %%
display(extensions_count_fix[extensions_count_fix['extensao']== 'No extension'])
display(extensions_count_fix[extensions_count_fix['extensao']== 'No file'])
#extensions_count['count'].sum()
extensions_count_fix['count'].sum()
# Out:
#         extensao  count
# 17  No extension    683
#    extensao  count
# 41  No file    221
# np.int64(66242)

# %%
unique_files = to_be_extensions_df[['filename','extensao']].drop_duplicates().groupby('extensao').count().reset_index()
unique_files['extensao'] = unique_files['extensao'].fillna('No file')
unique_files['extensao'] = unique_files['extensao'].replace('', 'No extension')
unique_files.sort_values('filename')
unique_files.sort_values('filename').to_csv(r'output_files\unique_files_extesions_count.csv',index = False)

# %%
exploded_test_df = explode_df(merged_df[merged_df['has_modified_test']])
extensions_count_test = extensions_count(exploded_test_df)
extensions_count_test.to_csv(r'output_files\(test)_files_extesions_count.csv',index = False)
display(extensions_count_test)
display(extensions_count_test[extensions_count_test['extensao']== 'No extension'])
extensions_count_test['count'].sum()
# Out:
#          extensao  count
# 0             .ts   6773
# 1             .py   4644
# 2           .html   3371
# 3            .out   2952
# 4             .rb   2319
# ..            ...    ...
# 320  .incremental      1
# 321         .phpt      1
# 322       .cypher      1
# 323      .service      1
# 324        .jsonl      1
#
# [325 rows x 2 columns]
#         extensao  count
# 19  No extension    448
# np.int64(46925)

# %%
test_unique_files = exploded_test_df[['filename','extensao']].drop_duplicates().groupby('extensao').count().reset_index()
test_unique_files['extensao'] = test_unique_files['extensao'].fillna('No file')
test_unique_files['extensao'] = test_unique_files['extensao'].replace('', 'No extension')
test_unique_files.sort_values('filename').to_csv(r'output_files\(test)_unique_files_extesions_count.csv',index = False)
#unique_files.sort_values('filename')
