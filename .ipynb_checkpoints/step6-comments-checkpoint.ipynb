# %%
from datasets import load_dataset
import pandas as pd
import ast
from collections import Counter
import requests
import time

# %%
reviews = pd.read_parquet('output_files/prs_reviews.parquet')
reduced_reviews = reviews[['id','number','agent','repo_url','html_url','closing_method','reviews_data','review_counts_map','has_human_closing_user']]

# %%
reduced_reviews
# Out:
#               id  number  agent  \
# 0     2438086945   88748  Human
# 1     2265431531   83085  Human
# 2     2622011651   94465  Human
# 3     2565399631   92785  Human
# 4     2374801945   86438  Human
# ...          ...     ...    ...
# 3318  3152227876    2121  Devin
# 3319  2876371914   54663  Devin
# 3320  3275451449    2766  Devin
# 3321  3260325787    1541  Devin
# 3322  3260452571    1542  Devin
#
#                                                repo_url  \
# 0         https://api.github.com/repos/getsentry/sentry
# 1         https://api.github.com/repos/getsentry/sentry
# 2         https://api.github.com/repos/getsentry/sentry
# 3         https://api.github.com/repos/getsentry/sentry
# 4         https://api.github.com/repos/getsentry/sentry
# ...                                                 ...
# 3318  https://api.github.com/repos/assistant-ui/assi...
# 3319     https://api.github.com/repos/airbytehq/airbyte
# 3320          https://api.github.com/repos/liam-hq/liam
# 3321  https://api.github.com/repos/reflex-dev/reflex...
# 3322  https://api.github.com/repos/reflex-dev/reflex...
#
#                                                html_url closing_method  \
# 0        https://github.com/getsentry/sentry/pull/88748         Merged
# 1        https://github.com/getsentry/sentry/pull/83085         Merged
# 2        https://github.com/getsentry/sentry/pull/94465         Merged
# 3        https://github.com/getsentry/sentry/pull/92785         Merged
# 4        https://github.com/getsentry/sentry/pull/86438         Merged
# ...                                                 ...            ...
# 3318  https://github.com/assistant-ui/assistant-ui/p...         Closed
# 3319    https://github.com/airbytehq/airbyte/pull/54663         Merged
# 3320          https://github.com/liam-hq/liam/pull/2766         Merged
# 3321  https://github.com/reflex-dev/reflex-web/pull/...         Merged
# 3322  https://github.com/reflex-dev/reflex-web/pull/...         Merged
#
#                                            reviews_data  \
# 0     [{'user': 'GabeVillalobos', 'state': 'COMMENTE...
# 1     [{'user': 'obostjancic', 'state': 'APPROVED', ...
# 2     [{'user': 'joshuarli', 'state': 'APPROVED', 'b...
# 3     [{'user': 'isabellaenriquez', 'state': 'APPROV...
# 4     [{'user': 'isabellaenriquez', 'state': 'APPROV...
# ...                                                 ...
# 3318  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3319  [{'user': 'pnilan', 'state': 'APPROVED', 'body...
# 3320  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 3321  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3322  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                                       review_counts_map  \
# 0                                 {'GabeVillalobos': 2}
# 1                                    {'obostjancic': 1}
# 2                                      {'joshuarli': 1}
# 3                               {'isabellaenriquez': 1}
# 4                  {'isabellaenriquez': 1, 'dashed': 1}
# ...                                                 ...
# 3318                          {'greptile-apps[bot]': 1}
# 3319                                      {'pnilan': 1}
# 3320  {'MH4GF': 3, 'copilot-pull-request-reviewer[bo...
# 3321           {'greptile-apps[bot]': 1, 'Lendemor': 1}
# 3322           {'greptile-apps[bot]': 1, 'Lendemor': 1}
#
#       has_human_closing_user
# 0                       True
# 1                       True
# 2                       True
# 3                       True
# 4                       True
# ...                      ...
# 3318                    True
# 3319                    True
# 3320                    True
# 3321                    True
# 3322                    True
#
# [3323 rows x 9 columns]

# %%
prs_with_review = reduced_reviews[reduced_reviews['reviews_data'].str.len() > 2]
rejected_prs_with_review = prs_with_review[prs_with_review['closing_method'] == 'Closed']
rejected_prs_with_review
# Out:
#               id  number  agent  \
# 14    2267246503   16263  Human
# 23    2489635620   19370  Human
# 28    2447030473   18877  Human
# 29    2399669336   18270  Human
# 71    2544110590    1480  Human
# ...          ...     ...    ...
# 3302  3159100053    2085  Devin
# 3306  3239945909    1524  Devin
# 3311  2895731914     728  Devin
# 3316  3007108786   20777  Devin
# 3318  3152227876    2121  Devin
#
#                                                repo_url  \
# 14             https://api.github.com/repos/oven-sh/bun
# 23             https://api.github.com/repos/oven-sh/bun
# 28             https://api.github.com/repos/oven-sh/bun
# 29             https://api.github.com/repos/oven-sh/bun
# 71       https://api.github.com/repos/RockChinQ/LangBot
# ...                                                 ...
# 3302          https://api.github.com/repos/liam-hq/liam
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agentops
# 3316        https://api.github.com/repos/calcom/cal.com
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                                html_url closing_method  \
# 14            https://github.com/oven-sh/bun/pull/16263         Closed
# 23            https://github.com/oven-sh/bun/pull/19370         Closed
# 28            https://github.com/oven-sh/bun/pull/18877         Closed
# 29            https://github.com/oven-sh/bun/pull/18270         Closed
# 71       https://github.com/RockChinQ/LangBot/pull/1480         Closed
# ...                                                 ...            ...
# 3302          https://github.com/liam-hq/liam/pull/2085         Closed
# 3306  https://github.com/reflex-dev/reflex-web/pull/...         Closed
# 3311   https://github.com/AgentOps-AI/agentops/pull/728         Closed
# 3316       https://github.com/calcom/cal.com/pull/20777         Closed
# 3318  https://github.com/assistant-ui/assistant-ui/p...         Closed
#
#                                            reviews_data  \
# 14    [{'user': 'paperclover', 'state': 'CHANGES_REQ...
# 23    [{'user': 'graphite-app[bot]', 'state': 'COMME...
# 28    [{'user': '190n', 'state': 'COMMENTED', 'body'...
# 29    [{'user': 'RiskyMH', 'state': 'APPROVED', 'bod...
# 71    [{'user': 'RockChinQ', 'state': 'CHANGES_REQUE...
# ...                                                 ...
# 3302  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 3306  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3311  [{'user': 'entelligence-ai-pr-reviews[bot]', '...
# 3316  [{'user': 'PeerRich', 'state': 'DISMISSED', 'b...
# 3318  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                                       review_counts_map  \
# 14                                   {'paperclover': 1}
# 23                             {'graphite-app[bot]': 1}
# 28                           {'190n': 2, 'DonIsaac': 1}
# 29                            {'RiskyMH': 1, 'alii': 1}
# 71                       {'RockChinQ': 1, 'erberry': 2}
# ...                                                 ...
# 3302                                       {'MH4GF': 6}
# 3306                          {'greptile-apps[bot]': 1}
# 3311             {'entelligence-ai-pr-reviews[bot]': 2}
# 3316  {'PeerRich': 1, 'cubic-dev-ai[bot]': 1, 'Tusha...
# 3318                          {'greptile-apps[bot]': 1}
#
#       has_human_closing_user
# 14                      True
# 23                      True
# 28                      True
# 29                      True
# 71                      True
# ...                      ...
# 3302                    True
# 3306                    True
# 3311                    True
# 3316                   False
# 3318                    True
#
# [484 rows x 9 columns]

# %%
rejected_prs_with_review_with_human_closing = rejected_prs_with_review[rejected_prs_with_review['has_human_closing_user'] == True]
rejected_prs_with_review_with_human_closing
# Out:
#               id  number  agent  \
# 14    2267246503   16263  Human
# 23    2489635620   19370  Human
# 28    2447030473   18877  Human
# 29    2399669336   18270  Human
# 71    2544110590    1480  Human
# ...          ...     ...    ...
# 3300  2949502900     376  Devin
# 3302  3159100053    2085  Devin
# 3306  3239945909    1524  Devin
# 3311  2895731914     728  Devin
# 3318  3152227876    2121  Devin
#
#                                                repo_url  \
# 14             https://api.github.com/repos/oven-sh/bun
# 23             https://api.github.com/repos/oven-sh/bun
# 28             https://api.github.com/repos/oven-sh/bun
# 29             https://api.github.com/repos/oven-sh/bun
# 71       https://api.github.com/repos/RockChinQ/LangBot
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302          https://api.github.com/repos/liam-hq/liam
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agentops
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                                html_url closing_method  \
# 14            https://github.com/oven-sh/bun/pull/16263         Closed
# 23            https://github.com/oven-sh/bun/pull/19370         Closed
# 28            https://github.com/oven-sh/bun/pull/18877         Closed
# 29            https://github.com/oven-sh/bun/pull/18270         Closed
# 71       https://github.com/RockChinQ/LangBot/pull/1480         Closed
# ...                                                 ...            ...
# 3300  https://github.com/different-ai/note-companion...         Closed
# 3302          https://github.com/liam-hq/liam/pull/2085         Closed
# 3306  https://github.com/reflex-dev/reflex-web/pull/...         Closed
# 3311   https://github.com/AgentOps-AI/agentops/pull/728         Closed
# 3318  https://github.com/assistant-ui/assistant-ui/p...         Closed
#
#                                            reviews_data  \
# 14    [{'user': 'paperclover', 'state': 'CHANGES_REQ...
# 23    [{'user': 'graphite-app[bot]', 'state': 'COMME...
# 28    [{'user': '190n', 'state': 'COMMENTED', 'body'...
# 29    [{'user': 'RiskyMH', 'state': 'APPROVED', 'bod...
# 71    [{'user': 'RockChinQ', 'state': 'CHANGES_REQUE...
# ...                                                 ...
# 3300  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3302  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 3306  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3311  [{'user': 'entelligence-ai-pr-reviews[bot]', '...
# 3318  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                            review_counts_map  has_human_closing_user
# 14                        {'paperclover': 1}                    True
# 23                  {'graphite-app[bot]': 1}                    True
# 28                {'190n': 2, 'DonIsaac': 1}                    True
# 29                 {'RiskyMH': 1, 'alii': 1}                    True
# 71            {'RockChinQ': 1, 'erberry': 2}                    True
# ...                                      ...                     ...
# 3300               {'greptile-apps[bot]': 1}                    True
# 3302                            {'MH4GF': 6}                    True
# 3306               {'greptile-apps[bot]': 1}                    True
# 3311  {'entelligence-ai-pr-reviews[bot]': 2}                    True
# 3318               {'greptile-apps[bot]': 1}                    True
#
# [438 rows x 9 columns]

# %%
agentic_rejected_prs_with_review_with_human_closing = rejected_prs_with_review_with_human_closing[rejected_prs_with_review_with_human_closing['agent'] != 'Human']
agentic_rejected_prs_with_review_with_human_closing
# Out:
#               id  number        agent  \
# 1089  3164503419      40  Claude_Code
# 1100  3138264959    1831  Claude_Code
# 1107  3197436829    1330  Claude_Code
# 1109  3209723205     149  Claude_Code
# 1117  2914277614   29902  Claude_Code
# ...          ...     ...          ...
# 3300  2949502900     376        Devin
# 3302  3159100053    2085        Devin
# 3306  3239945909    1524        Devin
# 3311  2895731914     728        Devin
# 3318  3152227876    2121        Devin
#
#                                                repo_url  \
# 1089  https://api.github.com/repos/amantus-ai/vibetu...
# 1100   https://api.github.com/repos/evmts/tevm-monorepo
# 1107   https://api.github.com/repos/giselles-ai/giselle
# 1109    https://api.github.com/repos/ruvnet/claude-flow
# 1117  https://api.github.com/repos/geneontology/go-o...
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302          https://api.github.com/repos/liam-hq/liam
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agentops
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                                html_url closing_method  \
# 1089   https://github.com/amantus-ai/vibetunnel/pull/40         Closed
# 1100   https://github.com/evmts/tevm-monorepo/pull/1831         Closed
# 1107   https://github.com/giselles-ai/giselle/pull/1330         Closed
# 1109     https://github.com/ruvnet/claude-flow/pull/149         Closed
# 1117  https://github.com/geneontology/go-ontology/pu...         Closed
# ...                                                 ...            ...
# 3300  https://github.com/different-ai/note-companion...         Closed
# 3302          https://github.com/liam-hq/liam/pull/2085         Closed
# 3306  https://github.com/reflex-dev/reflex-web/pull/...         Closed
# 3311   https://github.com/AgentOps-AI/agentops/pull/728         Closed
# 3318  https://github.com/assistant-ui/assistant-ui/p...         Closed
#
#                                            reviews_data  \
# 1089  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1100  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1107  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1109  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1117  [{'user': 'sjm41', 'state': 'APPROVED', 'body'...
# ...                                                 ...
# 3300  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3302  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 3306  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3311  [{'user': 'entelligence-ai-pr-reviews[bot]', '...
# 3318  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                               review_counts_map  has_human_closing_user
# 1089                   {'coderabbitai[bot]': 2}                    True
# 1100                   {'coderabbitai[bot]': 1}                    True
# 1107  {'copilot-pull-request-reviewer[bot]': 1}                    True
# 1109  {'copilot-pull-request-reviewer[bot]': 1}                    True
# 1117                               {'sjm41': 2}                    True
# ...                                         ...                     ...
# 3300                  {'greptile-apps[bot]': 1}                    True
# 3302                               {'MH4GF': 6}                    True
# 3306                  {'greptile-apps[bot]': 1}                    True
# 3311     {'entelligence-ai-pr-reviews[bot]': 2}                    True
# 3318                  {'greptile-apps[bot]': 1}                    True
#
# [365 rows x 9 columns]

# %%
agentic_rejected_prs_with_review_with_human_closing['review_comment_url'] = (
    agentic_rejected_prs_with_review_with_human_closing['repo_url'] 
    + '/pulls/' 
    + agentic_rejected_prs_with_review_with_human_closing['number'].astype(str) 
    + '/comments'
)

agentic_rejected_prs_with_review_with_human_closing['pr_comment_url'] = (
    agentic_rejected_prs_with_review_with_human_closing['repo_url'] 
    + '/issues/' 
    + agentic_rejected_prs_with_review_with_human_closing['number'].astype(str) 
    + '/comments'
)
agentic_rejected_prs_with_review_with_human_closing
# Out:
# C:\Users\Renato\AppData\Local\Temp\ipykernel_25568\4279591991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agentic_rejected_prs_with_review_with_human_closing['review_comment_url'] = (
# C:\Users\Renato\AppData\Local\Temp\ipykernel_25568\4279591991.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agentic_rejected_prs_with_review_with_human_closing['pr_comment_url'] = (
#               id  number        agent  \
# 1089  3164503419      40  Claude_Code
# 1100  3138264959    1831  Claude_Code
# 1107  3197436829    1330  Claude_Code
# 1109  3209723205     149  Claude_Code
# 1117  2914277614   29902  Claude_Code
# ...          ...     ...          ...
# 3300  2949502900     376        Devin
# 3302  3159100053    2085        Devin
# 3306  3239945909    1524        Devin
# 3311  2895731914     728        Devin
# 3318  3152227876    2121        Devin
#
#                                                repo_url  \
# 1089  https://api.github.com/repos/amantus-ai/vibetu...
# 1100   https://api.github.com/repos/evmts/tevm-monorepo
# 1107   https://api.github.com/repos/giselles-ai/giselle
# 1109    https://api.github.com/repos/ruvnet/claude-flow
# 1117  https://api.github.com/repos/geneontology/go-o...
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302          https://api.github.com/repos/liam-hq/liam
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agentops
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                                html_url closing_method  \
# 1089   https://github.com/amantus-ai/vibetunnel/pull/40         Closed
# 1100   https://github.com/evmts/tevm-monorepo/pull/1831         Closed
# 1107   https://github.com/giselles-ai/giselle/pull/1330         Closed
# 1109     https://github.com/ruvnet/claude-flow/pull/149         Closed
# 1117  https://github.com/geneontology/go-ontology/pu...         Closed
# ...                                                 ...            ...
# 3300  https://github.com/different-ai/note-companion...         Closed
# 3302          https://github.com/liam-hq/liam/pull/2085         Closed
# 3306  https://github.com/reflex-dev/reflex-web/pull/...         Closed
# 3311   https://github.com/AgentOps-AI/agentops/pull/728         Closed
# 3318  https://github.com/assistant-ui/assistant-ui/p...         Closed
#
#                                            reviews_data  \
# 1089  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1100  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1107  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1109  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1117  [{'user': 'sjm41', 'state': 'APPROVED', 'body'...
# ...                                                 ...
# 3300  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3302  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 3306  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3311  [{'user': 'entelligence-ai-pr-reviews[bot]', '...
# 3318  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                               review_counts_map  has_human_closing_user  \
# 1089                   {'coderabbitai[bot]': 2}                    True
# 1100                   {'coderabbitai[bot]': 1}                    True
# 1107  {'copilot-pull-request-reviewer[bot]': 1}                    True
# 1109  {'copilot-pull-request-reviewer[bot]': 1}                    True
# 1117                               {'sjm41': 2}                    True
# ...                                         ...                     ...
# 3300                  {'greptile-apps[bot]': 1}                    True
# 3302                               {'MH4GF': 6}                    True
# 3306                  {'greptile-apps[bot]': 1}                    True
# 3311     {'entelligence-ai-pr-reviews[bot]': 2}                    True
# 3318                  {'greptile-apps[bot]': 1}                    True
#
#                                      review_comment_url  \
# 1089  https://api.github.com/repos/amantus-ai/vibetu...
# 1100  https://api.github.com/repos/evmts/tevm-monore...
# 1107  https://api.github.com/repos/giselles-ai/gisel...
# 1109  https://api.github.com/repos/ruvnet/claude-flo...
# 1117  https://api.github.com/repos/geneontology/go-o...
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302  https://api.github.com/repos/liam-hq/liam/pull...
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agent...
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                          pr_comment_url
# 1089  https://api.github.com/repos/amantus-ai/vibetu...
# 1100  https://api.github.com/repos/evmts/tevm-monore...
# 1107  https://api.github.com/repos/giselles-ai/gisel...
# 1109  https://api.github.com/repos/ruvnet/claude-flo...
# 1117  https://api.github.com/repos/geneontology/go-o...
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302  https://api.github.com/repos/liam-hq/liam/issu...
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agent...
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
# [365 rows x 11 columns]

# %%
# Insira seu Token do GitHub aqui para aumentar o limite de requisições
GITHUB_TOKEN = "INSERT_TOKEN"
headers = {
    "Authorization": f"token {GITHUB_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

# %%
def fetch_review_comments(url):
    """
    Busca comentários de review e extrai: user(login, type), body, author_association
    """
    if not url or pd.isna(url):
        return []
    
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            comments = response.json()
            extracted_data = []
            for c in comments:
                # Extração segura usando .get() para evitar erros se a chave não existir
                user_data = c.get('user', {})
                extracted_data.append({
                    'user_login': user_data.get('login'),
                    'user_type': user_data.get('type'),
                    'body': c.get('body'),
                    'author_association': c.get('author_association')
                })
            return extracted_data
        else:
            print(f"Erro {response.status_code} na URL: {url}")
            return []
    except Exception as e:
        print(f"Erro de conexão: {e}")
        return []

def fetch_issue_comments(url):
    """
    Busca comentários da issue/PR e extrai os campos acima + performed_via_github_app
    """
    if not url or pd.isna(url):
        return []

    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            comments = response.json()
            extracted_data = []
            for c in comments:
                user_data = c.get('user', {})
                app_data = c.get('performed_via_github_app') # Pode ser None/Null
                
                # Tratamento para app data (pode ser None se for humano)
                app_slug = app_data.get('slug') if app_data else None
                app_name = app_data.get('name') if app_data else None

                extracted_data.append({
                    'user_login': user_data.get('login'),
                    'user_type': user_data.get('type'),
                    'body': c.get('body'),
                    'author_association': c.get('author_association'),
                    'app_slug': app_slug,
                    'app_name': app_name
                })
            return extracted_data
        else:
            print(f"Erro {response.status_code} na URL: {url}")
            return []
    except Exception as e:
        print(f"Erro de conexão: {e}")
        return []

# %%
print("Iniciando extração de Review Comments...")
agentic_rejected_prs_with_review_with_human_closing['review_comments_data'] = (
    agentic_rejected_prs_with_review_with_human_closing['review_comment_url']
    .apply(fetch_review_comments)
)

print("Iniciando extração de PR/Issue Comments...")
agentic_rejected_prs_with_review_with_human_closing['pr_comments_data'] = (
    agentic_rejected_prs_with_review_with_human_closing['pr_comment_url']
    .apply(fetch_issue_comments)
)

# Visualizando o resultado
print("Concluído!")
# Out:
# Iniciando extração de Review Comments...
# C:\Users\Renato\AppData\Local\Temp\ipykernel_25568\3113471259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agentic_rejected_prs_with_review_with_human_closing['review_comments_data'] = (
# Iniciando extração de PR/Issue Comments...
# Concluído!
# C:\Users\Renato\AppData\Local\Temp\ipykernel_25568\3113471259.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agentic_rejected_prs_with_review_with_human_closing['pr_comments_data'] = (

# %%
agentic_rejected_prs_with_review_with_human_closing
# Out:
#               id  number        agent  \
# 1089  3164503419      40  Claude_Code
# 1100  3138264959    1831  Claude_Code
# 1107  3197436829    1330  Claude_Code
# 1109  3209723205     149  Claude_Code
# 1117  2914277614   29902  Claude_Code
# ...          ...     ...          ...
# 3300  2949502900     376        Devin
# 3302  3159100053    2085        Devin
# 3306  3239945909    1524        Devin
# 3311  2895731914     728        Devin
# 3318  3152227876    2121        Devin
#
#                                                repo_url  \
# 1089  https://api.github.com/repos/amantus-ai/vibetu...
# 1100   https://api.github.com/repos/evmts/tevm-monorepo
# 1107   https://api.github.com/repos/giselles-ai/giselle
# 1109    https://api.github.com/repos/ruvnet/claude-flow
# 1117  https://api.github.com/repos/geneontology/go-o...
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302          https://api.github.com/repos/liam-hq/liam
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agentops
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                                html_url closing_method  \
# 1089   https://github.com/amantus-ai/vibetunnel/pull/40         Closed
# 1100   https://github.com/evmts/tevm-monorepo/pull/1831         Closed
# 1107   https://github.com/giselles-ai/giselle/pull/1330         Closed
# 1109     https://github.com/ruvnet/claude-flow/pull/149         Closed
# 1117  https://github.com/geneontology/go-ontology/pu...         Closed
# ...                                                 ...            ...
# 3300  https://github.com/different-ai/note-companion...         Closed
# 3302          https://github.com/liam-hq/liam/pull/2085         Closed
# 3306  https://github.com/reflex-dev/reflex-web/pull/...         Closed
# 3311   https://github.com/AgentOps-AI/agentops/pull/728         Closed
# 3318  https://github.com/assistant-ui/assistant-ui/p...         Closed
#
#                                            reviews_data  \
# 1089  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1100  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1107  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1109  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1117  [{'user': 'sjm41', 'state': 'APPROVED', 'body'...
# ...                                                 ...
# 3300  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3302  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 3306  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3311  [{'user': 'entelligence-ai-pr-reviews[bot]', '...
# 3318  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                               review_counts_map  has_human_closing_user  \
# 1089                   {'coderabbitai[bot]': 2}                    True
# 1100                   {'coderabbitai[bot]': 1}                    True
# 1107  {'copilot-pull-request-reviewer[bot]': 1}                    True
# 1109  {'copilot-pull-request-reviewer[bot]': 1}                    True
# 1117                               {'sjm41': 2}                    True
# ...                                         ...                     ...
# 3300                  {'greptile-apps[bot]': 1}                    True
# 3302                               {'MH4GF': 6}                    True
# 3306                  {'greptile-apps[bot]': 1}                    True
# 3311     {'entelligence-ai-pr-reviews[bot]': 2}                    True
# 3318                  {'greptile-apps[bot]': 1}                    True
#
#                                      review_comment_url  \
# 1089  https://api.github.com/repos/amantus-ai/vibetu...
# 1100  https://api.github.com/repos/evmts/tevm-monore...
# 1107  https://api.github.com/repos/giselles-ai/gisel...
# 1109  https://api.github.com/repos/ruvnet/claude-flo...
# 1117  https://api.github.com/repos/geneontology/go-o...
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302  https://api.github.com/repos/liam-hq/liam/pull...
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agent...
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                          pr_comment_url  \
# 1089  https://api.github.com/repos/amantus-ai/vibetu...
# 1100  https://api.github.com/repos/evmts/tevm-monore...
# 1107  https://api.github.com/repos/giselles-ai/gisel...
# 1109  https://api.github.com/repos/ruvnet/claude-flo...
# 1117  https://api.github.com/repos/geneontology/go-o...
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302  https://api.github.com/repos/liam-hq/liam/issu...
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agent...
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                    review_comments_data  \
# 1089  [{'user_login': 'coderabbitai[bot]', 'user_typ...
# 1100  [{'user_login': 'coderabbitai[bot]', 'user_typ...
# 1107  [{'user_login': 'Copilot', 'user_type': 'Bot',...
# 1109  [{'user_login': 'Copilot', 'user_type': 'Bot',...
# 1117                                                 []
# ...                                                 ...
# 3300                                                 []
# 3302  [{'user_login': 'MH4GF', 'user_type': 'User', ...
# 3306                                                 []
# 3311  [{'user_login': 'entelligence-ai-pr-reviews[bo...
# 3318  [{'user_login': 'greptile-apps[bot]', 'user_ty...
#
#                                        pr_comments_data
# 1089  [{'user_login': 'github-actions[bot]', 'user_t...
# 1100  [{'user_login': 'changeset-bot[bot]', 'user_ty...
# 1107  [{'user_login': 'changeset-bot[bot]', 'user_ty...
# 1109  [{'user_login': 'ruvnet', 'user_type': 'User',...
# 1117  [{'user_login': 'cmungall', 'user_type': 'User...
# ...                                                 ...
# 3300  [{'user_login': 'devin-ai-integration[bot]', '...
# 3302  [{'user_login': 'vercel[bot]', 'user_type': 'B...
# 3306  [{'user_login': 'devin-ai-integration[bot]', '...
# 3311  [{'user_login': 'devin-ai-integration[bot]', '...
# 3318  [{'user_login': 'entelligence-ai-pr-reviews[bo...
#
# [365 rows x 13 columns]

# %%
review_comments = agentic_rejected_prs_with_review_with_human_closing[['id', 'number', 'agent', 'html_url',
'reviews_data','review_comment_url','review_comments_data']]
review_comments
# Out:
#               id  number        agent  \
# 1089  3164503419      40  Claude_Code
# 1100  3138264959    1831  Claude_Code
# 1107  3197436829    1330  Claude_Code
# 1109  3209723205     149  Claude_Code
# 1117  2914277614   29902  Claude_Code
# ...          ...     ...          ...
# 3300  2949502900     376        Devin
# 3302  3159100053    2085        Devin
# 3306  3239945909    1524        Devin
# 3311  2895731914     728        Devin
# 3318  3152227876    2121        Devin
#
#                                                html_url  \
# 1089   https://github.com/amantus-ai/vibetunnel/pull/40
# 1100   https://github.com/evmts/tevm-monorepo/pull/1831
# 1107   https://github.com/giselles-ai/giselle/pull/1330
# 1109     https://github.com/ruvnet/claude-flow/pull/149
# 1117  https://github.com/geneontology/go-ontology/pu...
# ...                                                 ...
# 3300  https://github.com/different-ai/note-companion...
# 3302          https://github.com/liam-hq/liam/pull/2085
# 3306  https://github.com/reflex-dev/reflex-web/pull/...
# 3311   https://github.com/AgentOps-AI/agentops/pull/728
# 3318  https://github.com/assistant-ui/assistant-ui/p...
#
#                                            reviews_data  \
# 1089  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1100  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1107  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1109  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1117  [{'user': 'sjm41', 'state': 'APPROVED', 'body'...
# ...                                                 ...
# 3300  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3302  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 3306  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3311  [{'user': 'entelligence-ai-pr-reviews[bot]', '...
# 3318  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                                      review_comment_url  \
# 1089  https://api.github.com/repos/amantus-ai/vibetu...
# 1100  https://api.github.com/repos/evmts/tevm-monore...
# 1107  https://api.github.com/repos/giselles-ai/gisel...
# 1109  https://api.github.com/repos/ruvnet/claude-flo...
# 1117  https://api.github.com/repos/geneontology/go-o...
# ...                                                 ...
# 3300  https://api.github.com/repos/different-ai/note...
# 3302  https://api.github.com/repos/liam-hq/liam/pull...
# 3306  https://api.github.com/repos/reflex-dev/reflex...
# 3311  https://api.github.com/repos/AgentOps-AI/agent...
# 3318  https://api.github.com/repos/assistant-ui/assi...
#
#                                    review_comments_data
# 1089  [{'user_login': 'coderabbitai[bot]', 'user_typ...
# 1100  [{'user_login': 'coderabbitai[bot]', 'user_typ...
# 1107  [{'user_login': 'Copilot', 'user_type': 'Bot',...
# 1109  [{'user_login': 'Copilot', 'user_type': 'Bot',...
# 1117                                                 []
# ...                                                 ...
# 3300                                                 []
# 3302  [{'user_login': 'MH4GF', 'user_type': 'User', ...
# 3306                                                 []
# 3311  [{'user_login': 'entelligence-ai-pr-reviews[bo...
# 3318  [{'user_login': 'greptile-apps[bot]', 'user_ty...
#
# [365 rows x 7 columns]

# %%
comments_dataset = agentic_rejected_prs_with_review_with_human_closing[['id', 'number', 'agent', 'html_url',
       'reviews_data',
        'review_comments_data',
       'pr_comments_data']]
comments_dataset
# Out:
#               id  number        agent  \
# 1089  3164503419      40  Claude_Code
# 1100  3138264959    1831  Claude_Code
# 1107  3197436829    1330  Claude_Code
# 1109  3209723205     149  Claude_Code
# 1117  2914277614   29902  Claude_Code
# ...          ...     ...          ...
# 3300  2949502900     376        Devin
# 3302  3159100053    2085        Devin
# 3306  3239945909    1524        Devin
# 3311  2895731914     728        Devin
# 3318  3152227876    2121        Devin
#
#                                                html_url  \
# 1089   https://github.com/amantus-ai/vibetunnel/pull/40
# 1100   https://github.com/evmts/tevm-monorepo/pull/1831
# 1107   https://github.com/giselles-ai/giselle/pull/1330
# 1109     https://github.com/ruvnet/claude-flow/pull/149
# 1117  https://github.com/geneontology/go-ontology/pu...
# ...                                                 ...
# 3300  https://github.com/different-ai/note-companion...
# 3302          https://github.com/liam-hq/liam/pull/2085
# 3306  https://github.com/reflex-dev/reflex-web/pull/...
# 3311   https://github.com/AgentOps-AI/agentops/pull/728
# 3318  https://github.com/assistant-ui/assistant-ui/p...
#
#                                            reviews_data  \
# 1089  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1100  [{'user': 'coderabbitai[bot]', 'state': 'COMME...
# 1107  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1109  [{'user': 'copilot-pull-request-reviewer[bot]'...
# 1117  [{'user': 'sjm41', 'state': 'APPROVED', 'body'...
# ...                                                 ...
# 3300  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3302  [{'user': 'MH4GF', 'state': 'COMMENTED', 'body...
# 3306  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
# 3311  [{'user': 'entelligence-ai-pr-reviews[bot]', '...
# 3318  [{'user': 'greptile-apps[bot]', 'state': 'COMM...
#
#                                    review_comments_data  \
# 1089  [{'user_login': 'coderabbitai[bot]', 'user_typ...
# 1100  [{'user_login': 'coderabbitai[bot]', 'user_typ...
# 1107  [{'user_login': 'Copilot', 'user_type': 'Bot',...
# 1109  [{'user_login': 'Copilot', 'user_type': 'Bot',...
# 1117                                                 []
# ...                                                 ...
# 3300                                                 []
# 3302  [{'user_login': 'MH4GF', 'user_type': 'User', ...
# 3306                                                 []
# 3311  [{'user_login': 'entelligence-ai-pr-reviews[bo...
# 3318  [{'user_login': 'greptile-apps[bot]', 'user_ty...
#
#                                        pr_comments_data
# 1089  [{'user_login': 'github-actions[bot]', 'user_t...
# 1100  [{'user_login': 'changeset-bot[bot]', 'user_ty...
# 1107  [{'user_login': 'changeset-bot[bot]', 'user_ty...
# 1109  [{'user_login': 'ruvnet', 'user_type': 'User',...
# 1117  [{'user_login': 'cmungall', 'user_type': 'User...
# ...                                                 ...
# 3300  [{'user_login': 'devin-ai-integration[bot]', '...
# 3302  [{'user_login': 'vercel[bot]', 'user_type': 'B...
# 3306  [{'user_login': 'devin-ai-integration[bot]', '...
# 3311  [{'user_login': 'devin-ai-integration[bot]', '...
# 3318  [{'user_login': 'entelligence-ai-pr-reviews[bo...
#
# [365 rows x 7 columns]

# %%
all_reviews_type_subset = comments_dataset[['id','number','agent','html_url','reviews_data']]
all_reviews_type_subset["reviews_data_parsed"] = all_reviews_type_subset["reviews_data"].apply(
    lambda x: ast.literal_eval(x) if pd.notna(x) and x.strip() != "" else []
)

exploded_all_reviews_type_subset = (
    all_reviews_type_subset
        .explode("reviews_data_parsed")
        .reset_index(drop=True)
        .pipe(lambda d: pd.concat(
            [d.drop(columns=["reviews_data_parsed"]),
             pd.json_normalize(d["reviews_data_parsed"])],
            axis=1
        ))
)
exploded_all_reviews_type_subset.drop(['reviews_data','submitted_at'],inplace = True, axis = 1)

with_body_all_reviews_type_subset = exploded_all_reviews_type_subset[exploded_all_reviews_type_subset['body'] != '']
final_all_reviews_type_subset = with_body_all_reviews_type_subset[~with_body_all_reviews_type_subset['user'].str.contains('[bot]', regex=False, na=False)]
final_all_reviews_type_subset
# Out:
# C:\Users\Renato\AppData\Local\Temp\ipykernel_25568\258263794.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_reviews_type_subset["reviews_data_parsed"] = all_reviews_type_subset["reviews_data"].apply(
#              id  number        agent  \
# 5    2914277614   29902  Claude_Code
# 6    2914277614   29902  Claude_Code
# 7    2959025892   24145  Claude_Code
# 15   3234200031   16803      Copilot
# 16   3234200031   16803      Copilot
# ..          ...     ...          ...
# 869  3180830949   62108        Devin
# 882  3013552792    1458        Devin
# 889  2971334427   20541        Devin
# 892  3063938472     918        Devin
# 895  3063938472     918        Devin
#
#                                               html_url          user  \
# 5    https://github.com/geneontology/go-ontology/pu...         sjm41
# 6    https://github.com/geneontology/go-ontology/pu...         sjm41
# 7          https://github.com/apache/pulsar/pull/24145       lhotari
# 15   https://github.com/microsoft/vscode-jupyter/pu...  DonJayamanne
# 16   https://github.com/microsoft/vscode-jupyter/pu...  DonJayamanne
# ..                                                 ...           ...
# 869    https://github.com/airbytehq/airbyte/pull/62108      mwbayley
# 882          https://github.com/liam-hq/liam/pull/1458      junkisai
# 889       https://github.com/calcom/cal.com/pull/20541  TusharBhatt1
# 892      https://github.com/formancehq/ledger/pull/918        gfyrag
# 895      https://github.com/formancehq/ledger/pull/918        gfyrag
#
#                  state                                               body
# 5             APPROVED  Looks pretty good, thanks Claude (Chris)!\r\n\...
# 6             APPROVED                                    Looks good now!
# 7    CHANGES_REQUESTED                        Please address the feedback
# 15   CHANGES_REQUESTED  Read the following files and ONLY if you learn...
# 16   CHANGES_REQUESTED                  I want you to address my comments
# ..                 ...                                                ...
# 869  CHANGES_REQUESTED  Devin, this is incorrect. FileNotFoundError in...
# 882          COMMENTED                             I have left a comment!
# 889          COMMENTED  This PR has no issue related issue nor the det...
# 892  CHANGES_REQUESTED                  not tested.\r\nand probably wrong
# 895          COMMENTED                        Add integration tests noob!
#
# [139 rows x 7 columns]

# %%
review_comment_subset = comments_dataset[['id','number','agent','html_url','review_comments_data']]
exploded_review_comment_subset = (
    review_comment_subset[review_comment_subset["review_comments_data"].str.len() > 2]
        .explode("review_comments_data")
        .reset_index(drop=True)
        .pipe(lambda d: pd.concat(
            [d.drop(columns=["review_comments_data"]),
             pd.json_normalize(d["review_comments_data"])],
            axis=1
        ))
)
final_review_comment_subset = exploded_review_comment_subset
final_review_comment_subset
# Out:
#              id  number        agent  \
# 0    3164503419      40  Claude_Code
# 1    3164503419      40  Claude_Code
# 2    3164503419      40  Claude_Code
# 3    3164503419      40  Claude_Code
# 4    3164503419      40  Claude_Code
# ..          ...     ...          ...
# 585  3159100053    2085        Devin
# 586  3159100053    2085        Devin
# 587  3159100053    2085        Devin
# 588  3159100053    2085        Devin
# 589  3159100053    2085        Devin
#
#                                              html_url         user_login  \
# 0    https://github.com/amantus-ai/vibetunnel/pull/40  coderabbitai[bot]
# 1    https://github.com/amantus-ai/vibetunnel/pull/40  coderabbitai[bot]
# 2    https://github.com/amantus-ai/vibetunnel/pull/40  coderabbitai[bot]
# 3    https://github.com/amantus-ai/vibetunnel/pull/40  coderabbitai[bot]
# 4    https://github.com/amantus-ai/vibetunnel/pull/40  coderabbitai[bot]
# ..                                                ...                ...
# 585         https://github.com/liam-hq/liam/pull/2085              MH4GF
# 586         https://github.com/liam-hq/liam/pull/2085              MH4GF
# 587         https://github.com/liam-hq/liam/pull/2085              MH4GF
# 588         https://github.com/liam-hq/liam/pull/2085              MH4GF
# 589         https://github.com/liam-hq/liam/pull/2085              MH4GF
#
#     user_type                                               body  \
# 0         Bot  _⚠️ Potential issue_\n\n**Fix the callback unr...
# 1         Bot  _⚠️ Potential issue_\n\n**Move raw PTY callbac...
# 2         Bot  _⚠️ Potential issue_\n\n**Fix Go formatting is...
# 3         Bot  _⚠️ Potential issue_\n\n**Fix invalid CSS sele...
# 4         Bot  _⚠️ Potential issue_\n\n**Add synchronization ...
# ..        ...                                                ...
# 585      User                    Deleted because it is empty 👍🏻
# 586      User        Wraps with meaningless Fragment removed 👍🏻
# 587      User                            useCallback enforced 👀
# 588      User                           Unification by useId 👍🏻
# 589      User                       Enforce use of next/image 👀
#
#     author_association
# 0          CONTRIBUTOR
# 1          CONTRIBUTOR
# 2          CONTRIBUTOR
# 3          CONTRIBUTOR
# 4          CONTRIBUTOR
# ..                 ...
# 585             MEMBER
# 586             MEMBER
# 587             MEMBER
# 588             MEMBER
# 589             MEMBER
#
# [590 rows x 8 columns]

# %%
pr_comment_subset = comments_dataset[['id','number','agent','html_url','pr_comments_data']]
exploded_pr_comments_data = (
    pr_comment_subset[pr_comment_subset["pr_comments_data"].str.len() > 2]
        .explode("pr_comments_data")
        .reset_index(drop=True)
        .pipe(lambda d: pd.concat(
            [d.drop(columns=["pr_comments_data"]),
             pd.json_normalize(d["pr_comments_data"])],
            axis=1
        ))
)

final_pr_comments_data = exploded_pr_comments_data.drop(['app_slug','app_name'],axis = 1)
final_pr_comments_data
# Out:
#              id  number        agent  \
# 0    3164503419      40  Claude_Code
# 1    3164503419      40  Claude_Code
# 2    3164503419      40  Claude_Code
# 3    3164503419      40  Claude_Code
# 4    3164503419      40  Claude_Code
# ..          ...     ...          ...
# 790  3152227876    2121        Devin
# 791  3152227876    2121        Devin
# 792  3152227876    2121        Devin
# 793  3152227876    2121        Devin
# 794  3152227876    2121        Devin
#
#                                               html_url  \
# 0     https://github.com/amantus-ai/vibetunnel/pull/40
# 1     https://github.com/amantus-ai/vibetunnel/pull/40
# 2     https://github.com/amantus-ai/vibetunnel/pull/40
# 3     https://github.com/amantus-ai/vibetunnel/pull/40
# 4     https://github.com/amantus-ai/vibetunnel/pull/40
# ..                                                 ...
# 790  https://github.com/assistant-ui/assistant-ui/p...
# 791  https://github.com/assistant-ui/assistant-ui/p...
# 792  https://github.com/assistant-ui/assistant-ui/p...
# 793  https://github.com/assistant-ui/assistant-ui/p...
# 794  https://github.com/assistant-ui/assistant-ui/p...
#
#                     user_login user_type  \
# 0          github-actions[bot]       Bot
# 1            coderabbitai[bot]       Bot
# 2          github-actions[bot]       Bot
# 3          github-actions[bot]       Bot
# 4                     steipete      User
# ..                         ...       ...
# 790            promptless[bot]       Bot
# 791          jazzberry-ai[bot]       Bot
# 792  devin-ai-integration[bot]       Bot
# 793          jazzberry-ai[bot]       Bot
# 794              trag-bot[bot]       Bot
#
#                                                   body author_association
# 0    ## 🔍 Code Quality Report\n<!-- lint-results --...               NONE
# 1    <!-- This is an auto-generated comment: summar...        CONTRIBUTOR
# 2    ## ❌ CI Failed\n\n[View failed run](https://gi...               NONE
# 3    ## ❌ CI Failed\n\n[View failed run](https://gi...               NONE
# 4                                  burned it with fire       COLLABORATOR
# ..                                                 ...                ...
# 790               ✅ No documentation updates required.        CONTRIBUTOR
# 791  # Bug Report\n\nName | Severity | Example test...               NONE
# 792  ### 🤖 Devin AI Engineer\n\nI'll be helping wit...        CONTRIBUTOR
# 793  # Bug Report\n\n| Name | Severity | Example te...               NONE
# 794   @trag-bot didn't find any issues in the code! ✅✨               NONE
#
# [795 rows x 8 columns]

# %%
final_all_reviews_type_subset.to_csv(r'output_files/comments/comments_extracted_from_review_type.csv', index = False)
final_review_comment_subset[final_review_comment_subset['user_type'] == 'User'].to_csv(r'output_files/comments/comments_extracted_from_review_comment.csv', index = False)
final_pr_comments_data[final_pr_comments_data['user_type'] == 'User'].to_csv(r'output_files/comments/comments_extracted_from_pr_comment.csv', index = False)

# %%
final_review_comment_subset[final_review_comment_subset['user_type'] == 'User']
# Out:
#              id  number    agent  \
# 14   3268164028    7947  Copilot
# 15   3268164028    7947  Copilot
# 16   3268164028    7947  Copilot
# 20   3234115546     618  Copilot
# 21   3234115546     618  Copilot
# ..          ...     ...      ...
# 585  3159100053    2085    Devin
# 586  3159100053    2085    Devin
# 587  3159100053    2085    Devin
# 588  3159100053    2085    Devin
# 589  3159100053    2085    Devin
#
#                                             html_url user_login user_type  \
# 14   https://github.com/shader-slang/slang/pull/7947   csyonghe      User
# 15   https://github.com/shader-slang/slang/pull/7947   csyonghe      User
# 16   https://github.com/shader-slang/slang/pull/7947   csyonghe      User
# 20       https://github.com/Azure/azure-mcp/pull/618     jongio      User
# 21       https://github.com/Azure/azure-mcp/pull/618     jongio      User
# ..                                               ...        ...       ...
# 585        https://github.com/liam-hq/liam/pull/2085      MH4GF      User
# 586        https://github.com/liam-hq/liam/pull/2085      MH4GF      User
# 587        https://github.com/liam-hq/liam/pull/2085      MH4GF      User
# 588        https://github.com/liam-hq/liam/pull/2085      MH4GF      User
# 589        https://github.com/liam-hq/liam/pull/2085      MH4GF      User
#
#                                                   body author_association
# 14   instead of adding a `bool` parameter here, we ...       COLLABORATOR
# 15                                remove debug printf.       COLLABORATOR
# 16                                remove debug printf.       COLLABORATOR
# 20   I don't think this is necessary to rename this...             MEMBER
# 21                                ```suggestion\n\n```             MEMBER
# ..                                                 ...                ...
# 585                    Deleted because it is empty 👍🏻              MEMBER
# 586        Wraps with meaningless Fragment removed 👍🏻              MEMBER
# 587                            useCallback enforced 👀              MEMBER
# 588                           Unification by useId 👍🏻              MEMBER
# 589                       Enforce use of next/image 👀              MEMBER
#
# [300 rows x 8 columns]

# %%
final_pr_comments_data[final_pr_comments_data['user_type'] == 'User']
# Out:
#              id  number        agent  \
# 4    3164503419      40  Claude_Code
# 11   3197436829    1330  Claude_Code
# 14   3197436829    1330  Claude_Code
# 15   3197436829    1330  Claude_Code
# 16   2914277614   29902  Claude_Code
# ..          ...     ...          ...
# 761  3140927195    2167        Devin
# 763  3209745551    3113        Devin
# 764  3209745551    3113        Devin
# 766  3209745551    3113        Devin
# 767  3209745551    3113        Devin
#
#                                               html_url   user_login user_type  \
# 4     https://github.com/amantus-ai/vibetunnel/pull/40     steipete      User
# 11    https://github.com/giselles-ai/giselle/pull/1330        shige      User
# 14    https://github.com/giselles-ai/giselle/pull/1330        shige      User
# 15    https://github.com/giselles-ai/giselle/pull/1330        shige      User
# 16   https://github.com/geneontology/go-ontology/pu...     cmungall      User
# ..                                                 ...          ...       ...
# 761     https://github.com/onlook-dev/onlook/pull/2167     Kitenite      User
# 763      https://github.com/crewAIInc/crewAI/pull/3113  joaomdmoura      User
# 764      https://github.com/crewAIInc/crewAI/pull/3113  lucasgomide      User
# 766      https://github.com/crewAIInc/crewAI/pull/3113  lucasgomide      User
# 767      https://github.com/crewAIInc/crewAI/pull/3113   lorenzejay      User
#
#                                                   body author_association
# 4                                  burned it with fire       COLLABORATOR
# 11   📝 I was able to upgrade to Biome v2 with Claud...             MEMBER
# 14   > 📝 I was able to upgrade to Biome v2 with Cla...             MEMBER
# 15   > migrate at a later date.\r\n\r\nsee: https:/...             MEMBER
# 16   Claude, @sjm41 is correct, you should have als...             MEMBER
# ..                                                 ...                ...
# 761                  This seems to degrade performance        CONTRIBUTOR
# 763  Disclaimer: This review was made by a crew of ...       COLLABORATOR
# 764  Good work here. However the tests are still fa...        CONTRIBUTOR
# 766  @lorenzejay @Vidit-Ostwal did it also well.. h...        CONTRIBUTOR
# 767  > @lorenzejay @Vidit-Ostwal did it also well.....       COLLABORATOR
#
# [300 rows x 8 columns]

# %%
final_all_reviews_type_subset
# Out:
#              id  number        agent  \
# 5    2914277614   29902  Claude_Code
# 6    2914277614   29902  Claude_Code
# 7    2959025892   24145  Claude_Code
# 15   3234200031   16803      Copilot
# 16   3234200031   16803      Copilot
# ..          ...     ...          ...
# 869  3180830949   62108        Devin
# 882  3013552792    1458        Devin
# 889  2971334427   20541        Devin
# 892  3063938472     918        Devin
# 895  3063938472     918        Devin
#
#                                               html_url          user  \
# 5    https://github.com/geneontology/go-ontology/pu...         sjm41
# 6    https://github.com/geneontology/go-ontology/pu...         sjm41
# 7          https://github.com/apache/pulsar/pull/24145       lhotari
# 15   https://github.com/microsoft/vscode-jupyter/pu...  DonJayamanne
# 16   https://github.com/microsoft/vscode-jupyter/pu...  DonJayamanne
# ..                                                 ...           ...
# 869    https://github.com/airbytehq/airbyte/pull/62108      mwbayley
# 882          https://github.com/liam-hq/liam/pull/1458      junkisai
# 889       https://github.com/calcom/cal.com/pull/20541  TusharBhatt1
# 892      https://github.com/formancehq/ledger/pull/918        gfyrag
# 895      https://github.com/formancehq/ledger/pull/918        gfyrag
#
#                  state                                               body
# 5             APPROVED  Looks pretty good, thanks Claude (Chris)!\r\n\...
# 6             APPROVED                                    Looks good now!
# 7    CHANGES_REQUESTED                        Please address the feedback
# 15   CHANGES_REQUESTED  Read the following files and ONLY if you learn...
# 16   CHANGES_REQUESTED                  I want you to address my comments
# ..                 ...                                                ...
# 869  CHANGES_REQUESTED  Devin, this is incorrect. FileNotFoundError in...
# 882          COMMENTED                             I have left a comment!
# 889          COMMENTED  This PR has no issue related issue nor the det...
# 892  CHANGES_REQUESTED                  not tested.\r\nand probably wrong
# 895          COMMENTED                        Add integration tests noob!
#
# [139 rows x 7 columns]
